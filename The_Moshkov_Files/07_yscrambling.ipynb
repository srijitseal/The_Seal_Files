# %%
import pandas as pd

df = pd.read_csv("CP_count_PUMA.csv")
df
# Out:
#                                                   smiles  1_1  10_19  10_20  \
# 0            CCOC(=O)c1ccc(NC(=S)N2CCSC2c2ccc(OC)cc2)cc1  NaN    NaN    NaN
# 1                     O=C(CC1NC(=O)NC1=O)Nc1cccc2ccccc12  0.0    NaN    NaN
# 2                   CC(Nc1nc(nc2ccccc12)N1CCCC1)c1ccccc1  NaN    NaN    NaN
# 3      CCCC(Oc1ccc(Br)cc1)c1nc2c3cc(OC)c(OC)cc3nc(S)n2n1  NaN    NaN    NaN
# 4      CC1=C(C(NC(=O)N1)c1ccc(F)cc1)C(=O)OCc1ccc2OCOc2c1  NaN    NaN    NaN
# ...                                                  ...  ...    ...    ...
# 16165  COC(=O)[C@H]1[C@H](CO)[C@H]2Cn3c(=O)c(\C=C\C)c...  NaN    NaN    NaN
# 16166  C\C=C\c1ccc2n(C[C@H]3[C@H](CO)[C@H](N(C)[C@@H]...  NaN    NaN    NaN
# 16167  C\C=C\c1ccc2n(C[C@@H]3[C@@H](CO)[C@@H](N(C)[C@...  NaN    NaN    NaN
# 16168  C\C=C\c1ccc2n(C[C@H]3[C@H](CO)[C@@H](C(=O)N[C@...  NaN    NaN    NaN
# 16169  COC(=O)[C@@H]1[C@@H](CO)[C@@H]2Cn3c(=O)c(\C=C\...  NaN    NaN    NaN
#
#        100_277  100_278  104_291  105_355  105_369  105_361  ...  \
# 0          NaN      NaN      NaN      NaN      NaN      NaN  ...
# 1          NaN      NaN      NaN      NaN      NaN      NaN  ...
# 2          NaN      NaN      NaN      NaN      NaN      NaN  ...
# 3          NaN      NaN      NaN      NaN      NaN      NaN  ...
# 4          NaN      NaN      NaN      NaN      NaN      NaN  ...
# ...        ...      ...      ...      ...      ...      ...  ...
# 16165      NaN      NaN      NaN      NaN      NaN      NaN  ...
# 16166      NaN      NaN      NaN      NaN      NaN      NaN  ...
# 16167      NaN      NaN      NaN      NaN      NaN      NaN  ...
# 16168      NaN      NaN      NaN      NaN      NaN      NaN  ...
# 16169      NaN      NaN      NaN      NaN      NaN      NaN  ...
#
#        Cells_Neighbors_FirstClosestObjectNumber_Adjacent  \
# 0                                               1.765625
# 1                                               3.078125
# 2                                              -7.765625
# 3                                              -7.320312
# 4                                             -10.953125
# ...                                                  ...
# 16165                                          -2.039062
# 16166                                          -0.851562
# 16167                                          -3.851562
# 16168                                          -4.039062
# 16169                                          -3.210938
#
#        Cells_Neighbors_SecondClosestObjectNumber_5  \
# 0                                         0.890625
# 1                                         2.718750
# 2                                        -8.140625
# 3                                        -7.828125
# 4                                       -10.390625
# ...                                            ...
# 16165                                    -2.031250
# 16166                                    -0.359375
# 16167                                    -3.359375
# 16168                                    -2.460938
# 16169                                    -3.312500
#
#        Cells_Neighbors_SecondClosestObjectNumber_Adjacent  \
# 0                                               0.890625
# 1                                               2.718750
# 2                                              -8.140625
# 3                                              -7.828125
# 4                                             -10.390625
# ...                                                  ...
# 16165                                          -2.031250
# 16166                                          -0.359375
# 16167                                          -3.359375
# 16168                                          -2.460938
# 16169                                          -3.312500
#
#        Cells_Parent_Nuclei  Cytoplasm_Number_Object_Number  \
# 0                 1.328125                        1.328125
# 1                 2.503906                        2.503906
# 2                -8.250000                       -8.250000
# 3                -7.796875                       -7.804688
# 4               -10.960938                      -10.960938
# ...                    ...                             ...
# 16165            -1.550781                       -1.550781
# 16166            -0.835938                       -0.835938
# 16167            -3.835938                       -3.835938
# 16168            -3.300781                       -3.300781
# 16169            -3.308594                       -3.308594
#
#        Cytoplasm_Parent_Cells  Cytoplasm_Parent_Nuclei  \
# 0                    1.328125                 1.328125
# 1                    2.503906                 2.503906
# 2                   -8.250000                -8.250000
# 3                   -7.796875                -7.796875
# 4                  -10.960938               -10.960938
# ...                       ...                      ...
# 16165               -1.550781                -1.550781
# 16166               -0.835938                -0.835938
# 16167               -3.835938                -3.835938
# 16168               -3.300781                -3.300781
# 16169               -3.308594                -3.308594
#
#        Nuclei_Neighbors_FirstClosestObjectNumber_1  \
# 0                                         0.960938
# 1                                         3.242188
# 2                                        -7.710938
# 3                                        -7.859375
# 4                                       -11.406250
# ...                                            ...
# 16165                                    -1.546875
# 16166                                    -1.328125
# 16167                                    -3.328125
# 16168                                    -3.382812
# 16169                                    -3.804688
#
#        Nuclei_Neighbors_SecondClosestObjectNumber_1  \
# 0                                          1.320312
# 1                                          2.578125
# 2                                         -7.546875
# 3                                         -7.695312
# 4                                        -10.781250
# ...                                             ...
# 16165                                     -2.945312
# 16166                                     -0.804688
# 16167                                     -4.054688
# 16168                                     -2.937500
# 16169                                     -2.789062
#
#        Nuclei_Number_Object_Number
# 0                         1.328125
# 1                         2.503906
# 2                        -8.250000
# 3                        -7.804688
# 4                       -10.960938
# ...                            ...
# 16165                    -1.550781
# 16166                    -0.835938
# 16167                    -3.835938
# 16168                    -3.300781
# 16169                    -3.308594
#
# [16170 rows x 284 columns]

# %%
df.iloc[:, :271]
# Out:
#                                                   smiles  1_1  10_19  10_20  \
# 0            CCOC(=O)c1ccc(NC(=S)N2CCSC2c2ccc(OC)cc2)cc1  NaN    NaN    NaN
# 1                     O=C(CC1NC(=O)NC1=O)Nc1cccc2ccccc12  0.0    NaN    NaN
# 2                   CC(Nc1nc(nc2ccccc12)N1CCCC1)c1ccccc1  NaN    NaN    NaN
# 3      CCCC(Oc1ccc(Br)cc1)c1nc2c3cc(OC)c(OC)cc3nc(S)n2n1  NaN    NaN    NaN
# 4      CC1=C(C(NC(=O)N1)c1ccc(F)cc1)C(=O)OCc1ccc2OCOc2c1  NaN    NaN    NaN
# ...                                                  ...  ...    ...    ...
# 16165  COC(=O)[C@H]1[C@H](CO)[C@H]2Cn3c(=O)c(\C=C\C)c...  NaN    NaN    NaN
# 16166  C\C=C\c1ccc2n(C[C@H]3[C@H](CO)[C@H](N(C)[C@@H]...  NaN    NaN    NaN
# 16167  C\C=C\c1ccc2n(C[C@@H]3[C@@H](CO)[C@@H](N(C)[C@...  NaN    NaN    NaN
# 16168  C\C=C\c1ccc2n(C[C@H]3[C@H](CO)[C@@H](C(=O)N[C@...  NaN    NaN    NaN
# 16169  COC(=O)[C@@H]1[C@@H](CO)[C@@H]2Cn3c(=O)c(\C=C\...  NaN    NaN    NaN
#
#        100_277  100_278  104_291  105_355  105_369  105_361  ...  88_252  \
# 0          NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
# 1          NaN      NaN      NaN      NaN      NaN      NaN  ...     0.0
# 2          NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
# 3          NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
# 4          NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
# ...        ...      ...      ...      ...      ...      ...  ...     ...
# 16165      NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
# 16166      NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
# 16167      NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
# 16168      NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
# 16169      NaN      NaN      NaN      NaN      NaN      NaN  ...     NaN
#
#        88_254  89_255  9_14  9_17  9_18  90_256  91_257  92_258  93_259
# 0         NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# 1         NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# 2         NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# 3         NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# 4         NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# ...       ...     ...   ...   ...   ...     ...     ...     ...     ...
# 16165     NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# 16166     NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# 16167     NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# 16168     NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
# 16169     NaN     NaN   NaN   NaN   NaN     NaN     NaN     NaN     NaN
#
# [16170 rows x 271 columns]

# %%
assays_list = df.columns.to_list()[1:-13]
len(assays_list)
# Out:
# 270

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingClassifier


def load_and_preprocess_testdata(fold):
    test_path = f"PUMA/predictions/chemical_cv{fold}/assay_matrix_discrete_test_scaff.csv"

    
    test_data = pd.read_csv(test_path)[["smiles"]]
    test_data = pd.merge(test_data, df, on="smiles")
    
    return test_data

# %%
import numpy as np
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import GridSearchCV

# Initialize a list to store AUC scores for all folds
all_auc_scores = []

# Initialize an empty list to hold models for each fold
models_per_fold = []

# Define the fold indices (adjust based on your data split)
folds = ["0", "1", "2", "3", "4"]

# Predict for each individual fold using the corresponding model
for i in tqdm(range(0,25)):
    for idx, fold in enumerate(folds):
        # Load and preprocess data for the current test fold
        test_data = load_and_preprocess_testdata(fold)

        # Loop through each assay in the test set for the current fold
        for assay in (assays_list):
            test_data_assay = test_data[~test_data[assay].isna()][[assay, "Cells_Number_Object_Number"]]

            # Separate features and target variable
            y_test = test_data_assay[assay].astype(int)

            if len(y_test) == 0:
                print(f"Skipping assay {assay} in fold {fold} due to no test data")
                continue

            # Make predictions using the model for the current fold
            y_pred = np.random.permutation(y_test)

            # Calculate AUC score
            auc_score = np.nan    
            try:
                auc_score = roc_auc_score(y_test, y_pred)
            except:
                continue

            # Store the AUC score along with fold and assay information
            all_auc_scores.append({"Fold": fold, "Task": assay, "AUC": auc_score})

# Convert the AUC results to a DataFrame for convenience
auc_df = pd.DataFrame(all_auc_scores)

# Save the DataFrame to a CSV file
auc_df.to_csv("auc_scores_yscrambling.csv", index=False)

# Display the AUC DataFrame
auc_df
# Out:
# 100%|██████████| 25/25 [01:23<00:00,  3.33s/it]
#       Fold     Task       AUC
# 0        0      1_1  0.476190
# 1        0  100_277  0.437500
# 2        0  100_278  0.678571
# 3        0  104_291  0.384615
# 4        0  105_369  0.466667
# ...    ...      ...       ...
# 25270    4     9_18  0.300000
# 25271    4   90_256  0.482143
# 25272    4   91_257  0.375000
# 25273    4   92_258  0.375000
# 25274    4   93_259  0.350000
#
# [25275 rows x 3 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score

# Assuming df is your DataFrame and is already defined
num_iterations = 1  # Number of repetitions
thresholds = [0.5, 0.6, 0.7, 0.8, 0.9, 0.999]  # AUC thresholds


# Calculate mean AUC for each target across all iterations
mean_auc = auc_df[["Task", "AUC"]].groupby("Task").mean()

# Count the number of targets with AUC > 0.5, 0.7, 0.8, and 0.9
count_above_thresholds = {
    threshold: (mean_auc > threshold).sum() for threshold in thresholds
}

# Display results
print("Mean AUC for each target:")
print("\nNumber of targets with AUC > thresholds:")
print(count_above_thresholds)
# Out:
# Mean AUC for each target:
#
# Number of targets with AUC > thresholds:
# {0.5: AUC    134
# dtype: int64, 0.6: AUC    4
# dtype: int64, 0.7: AUC    0
# dtype: int64, 0.8: AUC    0
# dtype: int64, 0.9: AUC    0
# dtype: int64, 0.999: AUC    0
# dtype: int64}

# %%
mean_auc
# Out:
#               AUC
# Task
# 100_277  0.507067
# 100_278  0.495952
# 104_289  0.525974
# 104_291  0.513077
# 104_295  0.497143
# ...           ...
# 92_258   0.524286
# 93_259   0.502872
# 9_14     0.610000
# 9_17     0.520000
# 9_18     0.527333
#
# [269 rows x 1 columns]

# %%
mean_auc.mean()
# Out:
# AUC    0.502412
# dtype: float64

# %%
mean_auc.std()
# Out:
# AUC    0.025072
# dtype: float64
