# %%
import pandas as pd
from chembl_structure_pipeline import standardizer
from chembl_structure_pipeline import checker
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem import MolStandardize
# Out:
# [18:02:24] Initializing Normalizer

# %%
df = pd.read_csv("../../Cell_Painting_Median_Features_Median_doses.csv")
df
# Out:
#                                   InChICode_standardised    index  \
# 0      InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...    960.0
# 1      InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...   1036.0
# 2      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4942.5
# 3      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4944.5
# 4      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4949.5
# ...                                                  ...      ...
# 30399  InChI=1S/C9H9N5OS2/c10-12-8(16)11-6-3-1-2-5(4-...  30588.0
# 30400  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...  30589.0
# 30401  InChI=1S/C9H9NO2/c10-8-3-1-2-7(6-8)4-5-9(11)12...  30590.0
# 30402  InChI=1S/C9H9NO3S/c1-6(11)5-14-8-3-2-7(4-10-8)...  30591.0
# 30403  InChI=1S/C9H9NO5/c1-14-8-3-6(5-11)7(10(12)13)4...  30592.0
#
#        Metadata_mmoles_per_liter  Cells_AreaShape_Area  \
# 0                       5.000000           1728.953125
# 1                       5.000000           -272.074219
# 2                       4.973595            101.958984
# 3                       4.912934           -109.708984
# 4                       5.012874           -234.222656
# ...                          ...                   ...
# 30399                   5.000000           -226.027344
# 30400                   5.000000            254.769531
# 30401                   5.000000            238.574219
# 30402                   5.000000           -238.945312
# 30403                   5.000000            286.488281
#
#        Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0                     -1.375000                -25.445312
# 1                     11.464844                 -1.628906
# 2                     15.673828                 -2.314453
# 3                    -10.203125                  1.718750
# 4                      8.873047                  3.308594
# ...                         ...                       ...
# 30399                -18.847656                 -0.511719
# 30400                 18.886719                 -3.589844
# 30401                 -0.699219                  6.625000
# 30402                  5.476562                  0.089844
# 30403                  0.589844                 -3.125000
#
#        Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                        -0.067918                     -0.062396
# 1                        -0.001808                     -0.006674
# 2                         0.010687                      0.013397
# 3                         0.025025                      0.014627
# 4                         0.010192                      0.005251
# ...                            ...                           ...
# 30399                    -0.005827                      0.004864
# 30400                     0.027814                      0.016943
# 30401                     0.005228                      0.008800
# 30402                     0.018032                      0.012711
# 30403                     0.018058                      0.007385
#
#        Cells_AreaShape_EulerNumber  Cells_AreaShape_Extent  ...  \
# 0                              0.0                0.026443  ...
# 1                              0.0               -0.001405  ...
# 2                              0.0               -0.003746  ...
# 3                              0.0               -0.007164  ...
# 4                              0.0               -0.003173  ...
# ...                            ...                     ...  ...
# 30399                          0.0                0.003590  ...
# 30400                          0.0               -0.000781  ...
# 30401                          0.0                0.002336  ...
# 30402                          0.0               -0.004635  ...
# 30403                          0.0               -0.002819  ...
#
#        Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                            -0.218573                         0.314918
# 1                            -0.135188                         0.023860
# 2                             0.015253                        -0.014119
# 3                            -0.040388                         0.046218
# 4                             0.041850                        -0.072889
# ...                                ...                              ...
# 30399                        -0.201503                        -0.114357
# 30400                        -0.069652                        -0.079942
# 30401                         0.042933                        -0.107812
# 30402                         0.081551                        -0.070647
# 30403                        -0.076350                        -0.035772
#
#        Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                            0.222859                        0.280258
# 1                           -0.016903                       -0.017773
# 2                            0.035703                        0.016875
# 3                            0.031759                        0.037029
# 4                           -0.030955                       -0.037623
# ...                               ...                             ...
# 30399                       -0.123664                       -0.127474
# 30400                       -0.018155                       -0.017759
# 30401                       -0.107077                       -0.138399
# 30402                       -0.095379                       -0.102060
# 30403                       -0.069146                       -0.038609
#
#        Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                               0.192997                          0.144917
# 1                              -0.028029                         -0.038308
# 2                              -0.039304                         -0.070028
# 3                              -0.051411                         -0.083061
# 4                              -0.009460                          0.004604
# ...                                  ...                               ...
# 30399                          -0.069665                         -0.056972
# 30400                          -0.118369                         -0.046322
# 30401                           0.168811                          0.216703
# 30402                           0.023423                          0.049321
# 30403                          -0.023672                         -0.021189
#
#        Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                              0.168085                         -0.332871
# 1                             -0.041455                         -0.070389
# 2                             -0.062892                         -0.015647
# 3                             -0.071562                         -0.024598
# 4                             -0.010465                         -0.031869
# ...                                 ...                               ...
# 30399                         -0.044186                         -0.019668
# 30400                         -0.023926                          0.033498
# 30401                          0.195851                         -0.063656
# 30402                          0.041996                          0.023470
# 30403                         -0.042713                          0.020877
#
#        Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                            -0.314733                        -0.313477
# 1                            -0.067789                        -0.071673
# 2                            -0.038908                        -0.026464
# 3                            -0.052021                        -0.043327
# 4                            -0.025910                        -0.014907
# ...                                ...                              ...
# 30399                        -0.091541                        -0.062515
# 30400                         0.051214                         0.016060
# 30401                        -0.042877                        -0.071681
# 30402                         0.058959                         0.065934
# 30403                         0.020216                         0.045447
#
# [30404 rows x 1786 columns]

# %%
df.iloc[1]["InChICode_standardised"]
# Out:
# 'InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(3)12(16)18)13-8(14-10)6-19-4/h7H,5-6H2,1-4H3,(H,13,14)'

# %%
# !pwd
# Out:
# /dgx1nas1/storage/data/seal/The_Seal_Files/The_Seal_dataset/Generate_data

# %%
df.InChICode_standardised.nunique()
# Out:
# 30404

# %%
from rdkit import Chem
from rdkit.Chem import MolStandardize

def standardize_SMILES(InChICode_standardised):
    try:
        # Convert SMILES string to RDKit Mol object
        mol = Chem.MolFromInchi(InChICode_standardised)
        if mol is None:
            return "Invalid_SMILES"

        # Initialize RDKit standardizer components
        desalter = MolStandardize.fragment.LargestFragmentChooser()
        normalizer = MolStandardize.normalize.Normalizer()
        uncharger = MolStandardize.charge.Uncharger()

        # Step 1: Choose the largest fragment
        largest_fragment = desalter.choose(mol)

        # Step 2: Normalize the molecule (handle tautomeric forms, etc.)
        normalized_mol = normalizer.normalize(largest_fragment)

        # Step 3: Remove charges
        uncharged_mol = uncharger.uncharge(normalized_mol)

        # Step 4: Remove stereochemistry (if desired)
        Chem.RemoveStereochemistry(uncharged_mol)

        # Convert back to SMILES
        smiles_standardized = Chem.MolToSmiles(uncharged_mol)

        return smiles_standardized
    
    except Exception as e:
        # Log or print the error if needed
        print(f"Error standardizing SMILES: {e}")
        return "Cannot_do"

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True, nb_workers=80)
# Out:
# INFO: Pandarallel will run on 80 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
import pandas as pd 
from tqdm import tqdm 
import time 

RDLogger.DisableLog('rdApp.info')  
tqdm.pandas()

# %%
df["Standardized_SMILES_chembl"] = df["InChICode_standardised"].parallel_apply(standardize_SMILES)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=381), Label(value='0 / 381'))), HB…
# [18:03:29] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 6
# [18:03:30] WARNING: not removing hydrogen atom without neighbors
# [18:03:30] WARNING: not removing hydrogen atom without neighbors

# %%
RDLogger.DisableLog('rdApp.*')  
def smiles_to_inchi(smiles):
    
    try:
        # Read SMILES and convert it to RDKit mol object
        mol = Chem.MolFromSmiles(smiles)
        inchi_standardized = Chem.MolToInchi(mol)

        return inchi_standardized
    
    except:
        return "Cannot_do"

# %%
df["Standardized_InChI_chembl"] = df["Standardized_SMILES_chembl"].parallel_apply(smiles_to_inchi)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=381), Label(value='0 / 381'))), HB…

# %%
df
# Out:
#                                   InChICode_standardised    index  \
# 0      InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...    960.0
# 1      InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...   1036.0
# 2      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4942.5
# 3      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4944.5
# 4      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4949.5
# ...                                                  ...      ...
# 30399  InChI=1S/C9H9N5OS2/c10-12-8(16)11-6-3-1-2-5(4-...  30588.0
# 30400  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...  30589.0
# 30401  InChI=1S/C9H9NO2/c10-8-3-1-2-7(6-8)4-5-9(11)12...  30590.0
# 30402  InChI=1S/C9H9NO3S/c1-6(11)5-14-8-3-2-7(4-10-8)...  30591.0
# 30403  InChI=1S/C9H9NO5/c1-14-8-3-6(5-11)7(10(12)13)4...  30592.0
#
#        Metadata_mmoles_per_liter  Cells_AreaShape_Area  \
# 0                       5.000000           1728.953125
# 1                       5.000000           -272.074219
# 2                       4.973595            101.958984
# 3                       4.912934           -109.708984
# 4                       5.012874           -234.222656
# ...                          ...                   ...
# 30399                   5.000000           -226.027344
# 30400                   5.000000            254.769531
# 30401                   5.000000            238.574219
# 30402                   5.000000           -238.945312
# 30403                   5.000000            286.488281
#
#        Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0                     -1.375000                -25.445312
# 1                     11.464844                 -1.628906
# 2                     15.673828                 -2.314453
# 3                    -10.203125                  1.718750
# 4                      8.873047                  3.308594
# ...                         ...                       ...
# 30399                -18.847656                 -0.511719
# 30400                 18.886719                 -3.589844
# 30401                 -0.699219                  6.625000
# 30402                  5.476562                  0.089844
# 30403                  0.589844                 -3.125000
#
#        Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                        -0.067918                     -0.062396
# 1                        -0.001808                     -0.006674
# 2                         0.010687                      0.013397
# 3                         0.025025                      0.014627
# 4                         0.010192                      0.005251
# ...                            ...                           ...
# 30399                    -0.005827                      0.004864
# 30400                     0.027814                      0.016943
# 30401                     0.005228                      0.008800
# 30402                     0.018032                      0.012711
# 30403                     0.018058                      0.007385
#
#        Cells_AreaShape_EulerNumber  Cells_AreaShape_Extent  ...  \
# 0                              0.0                0.026443  ...
# 1                              0.0               -0.001405  ...
# 2                              0.0               -0.003746  ...
# 3                              0.0               -0.007164  ...
# 4                              0.0               -0.003173  ...
# ...                            ...                     ...  ...
# 30399                          0.0                0.003590  ...
# 30400                          0.0               -0.000781  ...
# 30401                          0.0                0.002336  ...
# 30402                          0.0               -0.004635  ...
# 30403                          0.0               -0.002819  ...
#
#        Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                            0.222859                        0.280258
# 1                           -0.016903                       -0.017773
# 2                            0.035703                        0.016875
# 3                            0.031759                        0.037029
# 4                           -0.030955                       -0.037623
# ...                               ...                             ...
# 30399                       -0.123664                       -0.127474
# 30400                       -0.018155                       -0.017759
# 30401                       -0.107077                       -0.138399
# 30402                       -0.095379                       -0.102060
# 30403                       -0.069146                       -0.038609
#
#        Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                               0.192997                          0.144917
# 1                              -0.028029                         -0.038308
# 2                              -0.039304                         -0.070028
# 3                              -0.051411                         -0.083061
# 4                              -0.009460                          0.004604
# ...                                  ...                               ...
# 30399                          -0.069665                         -0.056972
# 30400                          -0.118369                         -0.046322
# 30401                           0.168811                          0.216703
# 30402                           0.023423                          0.049321
# 30403                          -0.023672                         -0.021189
#
#        Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                              0.168085                         -0.332871
# 1                             -0.041455                         -0.070389
# 2                             -0.062892                         -0.015647
# 3                             -0.071562                         -0.024598
# 4                             -0.010465                         -0.031869
# ...                                 ...                               ...
# 30399                         -0.044186                         -0.019668
# 30400                         -0.023926                          0.033498
# 30401                          0.195851                         -0.063656
# 30402                          0.041996                          0.023470
# 30403                         -0.042713                          0.020877
#
#        Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0  \
# 0                            -0.314733                        -0.313477
# 1                            -0.067789                        -0.071673
# 2                            -0.038908                        -0.026464
# 3                            -0.052021                        -0.043327
# 4                            -0.025910                        -0.014907
# ...                                ...                              ...
# 30399                        -0.091541                        -0.062515
# 30400                         0.051214                         0.016060
# 30401                        -0.042877                        -0.071681
# 30402                         0.058959                         0.065934
# 30403                         0.020216                         0.045447
#
#                    Standardized_SMILES_chembl  \
# 0            COC(O)=Nc1nc2ccc(SC(C)C)cc2[nH]1
# 1      COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 2         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# 3         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# 4         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# ...                                       ...
# 30399           NNC(S)=Nc1cccc(-c2nnc(S)o2)c1
# 30400                      OCc1c[nH]c2ccccc12
# 30401                    Nc1cccc(C=CC(=O)O)c1
# 30402                CC(=O)CSc1ccc(C(=O)O)cn1
# 30403         COc1cc(C=O)c([N+](=O)[O-])cc1OC
#
#                                Standardized_InChI_chembl
# 0      InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1      InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 3      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 4      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# ...                                                  ...
# 30399  InChI=1S/C9H9N5OS2/c10-12-8(16)11-6-3-1-2-5(4-...
# 30400  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...
# 30401  InChI=1S/C9H9NO2/c10-8-3-1-2-7(6-8)4-5-9(11)12...
# 30402  InChI=1S/C9H9NO3S/c1-6(11)5-14-8-3-2-7(4-10-8)...
# 30403  InChI=1S/C9H9NO5/c1-14-8-3-6(5-11)7(10(12)13)4...
#
# [30404 rows x 1788 columns]

# %%
RDLogger.DisableLog('rdApp.*')  
def smiles_to_inchikey(smiles):
    
    try:
        # Read SMILES and convert it to RDKit mol object
        mol = Chem.MolFromSmiles(smiles)
        inchikey_standardized = Chem.MolToInchiKey(mol)

        return inchikey_standardized
    
    except:
        return "Cannot_do"

# %%
df["Standardized_InChIKey_chembl"] = df["Standardized_SMILES_chembl"].parallel_apply(smiles_to_inchikey)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=381), Label(value='0 / 381'))), HB…

# %%
df = df[["InChICode_standardised", "Standardized_SMILES_chembl", "Standardized_InChI_chembl", "Standardized_InChIKey_chembl"]]
df
# Out:
#                                   InChICode_standardised  \
# 0      InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1      InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 3      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 4      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# ...                                                  ...
# 30399  InChI=1S/C9H9N5OS2/c10-12-8(16)11-6-3-1-2-5(4-...
# 30400  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...
# 30401  InChI=1S/C9H9NO2/c10-8-3-1-2-7(6-8)4-5-9(11)12...
# 30402  InChI=1S/C9H9NO3S/c1-6(11)5-14-8-3-2-7(4-10-8)...
# 30403  InChI=1S/C9H9NO5/c1-14-8-3-6(5-11)7(10(12)13)4...
#
#                    Standardized_SMILES_chembl  \
# 0            COC(O)=Nc1nc2ccc(SC(C)C)cc2[nH]1
# 1      COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 2         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# 3         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# 4         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# ...                                       ...
# 30399           NNC(S)=Nc1cccc(-c2nnc(S)o2)c1
# 30400                      OCc1c[nH]c2ccccc12
# 30401                    Nc1cccc(C=CC(=O)O)c1
# 30402                CC(=O)CSc1ccc(C(=O)O)cn1
# 30403         COc1cc(C=O)c([N+](=O)[O-])cc1OC
#
#                                Standardized_InChI_chembl  \
# 0      InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1      InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 3      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 4      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# ...                                                  ...
# 30399  InChI=1S/C9H9N5OS2/c10-12-8(16)11-6-3-1-2-5(4-...
# 30400  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...
# 30401  InChI=1S/C9H9NO2/c10-8-3-1-2-7(6-8)4-5-9(11)12...
# 30402  InChI=1S/C9H9NO3S/c1-6(11)5-14-8-3-2-7(4-10-8)...
# 30403  InChI=1S/C9H9NO5/c1-14-8-3-6(5-11)7(10(12)13)4...
#
#       Standardized_InChIKey_chembl
# 0      SXJIZQPZESTWLD-UHFFFAOYSA-N
# 1      NBLBCGUCPBXKOV-UHFFFAOYSA-N
# 2      FOLOUAULJSJVDY-UHFFFAOYSA-N
# 3      FOLOUAULJSJVDY-UHFFFAOYSA-N
# 4      FOLOUAULJSJVDY-UHFFFAOYSA-N
# ...                            ...
# 30399  LHXWPDUWZAYBJV-UHFFFAOYSA-N
# 30400  IVYPNXXAYMYVSP-UHFFFAOYSA-N
# 30401  JNXMJSYJCFTLJB-UHFFFAOYSA-N
# 30402  LRBIKSYRCFHKBN-UHFFFAOYSA-N
# 30403  YWSPWKXREVSQCA-UHFFFAOYSA-N
#
# [30404 rows x 4 columns]

# %%
df.Standardized_InChIKey_chembl.nunique()
# Out:
# 15409

# %%
df.to_csv("Bray_compounds_processed_chembl_identifiers.csv.gz", index=False, compression="gzip")

# %%
import pandas as pd
df = pd.read_csv("Bray_compounds_processed_chembl_identifiers.csv.gz", compression="gzip")
df
# Out:
#                                   InChICode_standardised  \
# 0      InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1      InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 3      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 4      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# ...                                                  ...
# 30399  InChI=1S/C9H9N5OS2/c10-12-8(16)11-6-3-1-2-5(4-...
# 30400  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...
# 30401  InChI=1S/C9H9NO2/c10-8-3-1-2-7(6-8)4-5-9(11)12...
# 30402  InChI=1S/C9H9NO3S/c1-6(11)5-14-8-3-2-7(4-10-8)...
# 30403  InChI=1S/C9H9NO5/c1-14-8-3-6(5-11)7(10(12)13)4...
#
#                    Standardized_SMILES_chembl  \
# 0            COC(O)=Nc1nc2ccc(SC(C)C)cc2[nH]1
# 1      COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 2         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# 3         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# 4         CNCC1OCc2cnnn2CCCC(=O)N(C(C)CO)CC1C
# ...                                       ...
# 30399           NNC(S)=Nc1cccc(-c2nnc(S)o2)c1
# 30400                      OCc1c[nH]c2ccccc12
# 30401                    Nc1cccc(C=CC(=O)O)c1
# 30402                CC(=O)CSc1ccc(C(=O)O)cn1
# 30403         COc1cc(C=O)c([N+](=O)[O-])cc1OC
#
#                                Standardized_InChI_chembl  \
# 0      InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1      InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 3      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# 4      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...
# ...                                                  ...
# 30399  InChI=1S/C9H9N5OS2/c10-12-8(16)11-6-3-1-2-5(4-...
# 30400  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...
# 30401  InChI=1S/C9H9NO2/c10-8-3-1-2-7(6-8)4-5-9(11)12...
# 30402  InChI=1S/C9H9NO3S/c1-6(11)5-14-8-3-2-7(4-10-8)...
# 30403  InChI=1S/C9H9NO5/c1-14-8-3-6(5-11)7(10(12)13)4...
#
#       Standardized_InChIKey_chembl
# 0      SXJIZQPZESTWLD-UHFFFAOYSA-N
# 1      NBLBCGUCPBXKOV-UHFFFAOYSA-N
# 2      FOLOUAULJSJVDY-UHFFFAOYSA-N
# 3      FOLOUAULJSJVDY-UHFFFAOYSA-N
# 4      FOLOUAULJSJVDY-UHFFFAOYSA-N
# ...                            ...
# 30399  LHXWPDUWZAYBJV-UHFFFAOYSA-N
# 30400  IVYPNXXAYMYVSP-UHFFFAOYSA-N
# 30401  JNXMJSYJCFTLJB-UHFFFAOYSA-N
# 30402  LRBIKSYRCFHKBN-UHFFFAOYSA-N
# 30403  YWSPWKXREVSQCA-UHFFFAOYSA-N
#
# [30404 rows x 4 columns]

# %%
from chembl_webresource_client.new_client import new_client

# Set up the ChEMBL client
chembl_client = new_client

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True, nb_workers=80)
# Out:
# INFO: Pandarallel will run on 80 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
def smiles_to_chembl_id(smiles):
    try:
        molecule = chembl_client.molecule
        result = molecule.filter(smiles=smiles).only("molecule_chembl_id")
        return result[0]["molecule_chembl_id"] if result else None
    except Exception as e:
        print(f"Error converting SMILES to ChEMBL ID for {smiles}: {e}")
        return "Cannot_do"

# %%
from tqdm import tqdm
import pandas as pd

# Initialize tqdm for pandas
tqdm.pandas()


# Apply the function to each row with progress bar
df['ChEMBL_ID'] = df['Standardized_SMILES_chembl'].progress_apply(smiles_to_chembl_id)

# Display the updated DataFrame
df
# Out:
#   0%|          | 93/30404 [00:15<1:22:11,  6.15it/s]
#
# KeyboardInterrupt

# %%
df.ChEMBL_ID.nunique()

# %%
df.to_csv("Bray_compounds_processed_chembl_identifiers.csv.gz", index=False, compression="gzip")
