# %%
import pandas as pd

# %%
df = pd.read_csv("Generate_data/targetannotations_singleproteins_braycompounds_1543.csv", sep = ",")
df
# Out:
#                                  InChICode_standardised  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1408  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1409  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1410  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1411  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1412  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#                              Standardized_SMILES_chembl  \
# 0                      COC(=O)Nc1nc2ccc(SC(C)C)cc2[nH]1
# 1                COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 2                 Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 3     CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 4                               CC1=NN(c2ccccc2)C(=O)C1
# ...                                                 ...
# 1408                         CCn1c(O)nc2cc(Cl)c(Cl)cc21
# 1409                              Cc1nc(O)c2cccc(O)c2n1
# 1410                        N=C(N)NC(=O)Cc1c(Cl)cccc1Cl
# 1411                       Nc1ccc(S(=O)(=O)Nc2nccs2)cc1
# 1412                        Cc1no[nH]c1=NC(=O)Nc1cccnc1
#
#                               Standardized_InChI_chembl  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1408  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1409  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1410  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1411  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1412  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#      Standardized_InChIKey_chembl      ChEMBL_ID molecule_chembl_id  \
# 0     SXJIZQPZESTWLD-UHFFFAOYSA-N  CHEMBL1354363      CHEMBL1354363
# 1     NBLBCGUCPBXKOV-UHFFFAOYSA-N   CHEMBL307639       CHEMBL307639
# 2     COBBNRKBTCBWQP-UHFFFAOYSA-N  CHEMBL1371756      CHEMBL1371756
# 3     GUGOEEXESWIERI-UHFFFAOYSA-N    CHEMBL17157        CHEMBL17157
# 4     QELUYTUMUWHWMC-UHFFFAOYSA-N   CHEMBL290916       CHEMBL290916
# ...                           ...            ...                ...
# 1408  LKHRMULASXZCLG-UHFFFAOYSA-N  CHEMBL1255655      CHEMBL1255655
# 1409  YJDAOHJWLUNFLX-UHFFFAOYSA-N   CHEMBL123904       CHEMBL123904
# 1410  INJOMKTZOLKMBF-UHFFFAOYSA-N      CHEMBL862          CHEMBL862
# 1411  JNMRHUJNCSQMMB-UHFFFAOYSA-N      CHEMBL437          CHEMBL437
# 1412  NXRCDGIGKSHKAP-UHFFFAOYSA-N  CHEMBL1710820      CHEMBL1710820
#
#       CHEMBL1613870  CHEMBL1741321  CHEMBL1741322  CHEMBL1741323  ...  \
# 0               NaN            0.0            1.0            NaN  ...
# 1               NaN            0.0            1.0            0.0  ...
# 2               NaN            1.0            1.0            NaN  ...
# 3               NaN            NaN            NaN            NaN  ...
# 4               NaN            0.0            1.0            0.0  ...
# ...             ...            ...            ...            ...  ...
# 1408            NaN            NaN            1.0            0.0  ...
# 1409            NaN            1.0            1.0            1.0  ...
# 1410            NaN            0.0            0.0            0.0  ...
# 1411            NaN            0.0            0.0            0.0  ...
# 1412            NaN            0.0            1.0            0.0  ...
#
#       CHEMBL5291823  CHEMBL5291828  CHEMBL5291850  CHEMBL5291863  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               0.0            1.0            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 1408            NaN            NaN            NaN            NaN
# 1409            NaN            NaN            NaN            NaN
# 1410            0.0            NaN            NaN            NaN
# 1411            NaN            NaN            NaN            NaN
# 1412            NaN            NaN            NaN            NaN
#
#       CHEMBL5291882  CHEMBL5291891  CHEMBL5291892  CHEMBL5291899  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               0.0            0.0            NaN            0.0
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 1408            NaN            NaN            NaN            NaN
# 1409            NaN            NaN            NaN            NaN
# 1410            NaN            NaN            NaN            0.0
# 1411            NaN            NaN            0.0            NaN
# 1412            NaN            NaN            NaN            NaN
#
#       CHEMBL5291901  CHEMBL5291911
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 1408            NaN            NaN
# 1409            NaN            NaN
# 1410            NaN            NaN
# 1411            NaN            NaN
# 1412            NaN            NaN
#
# [1413 rows x 63 columns]

# %%
df.columns.to_list()[:5]
# Out:
# ['InChICode_standardised',
#  'Standardized_SMILES_chembl',
#  'Standardized_InChI_chembl',
#  'Standardized_InChIKey_chembl',
#  'ChEMBL_ID']

# %%
df["CHEMBL1613870"].value_counts()
# Out:
# 1.0    49
# 0.0    10
# Name: CHEMBL1613870, dtype: int64

# %%
# Create a list to keep track of columns meeting the condition
columns_to_keep = []

# Iterate over columns starting from the 6th column onward
for col in df.columns[6:]:
    # Check if all value counts are at least 20
    if (df[col].value_counts() >= 20).all():
        columns_to_keep.append(col)

# Subset the DataFrame to include only these columns
filtered_df = df[df.columns.to_list()[:5] + columns_to_keep]

# Display the resulting DataFrame
filtered_df
# Out:
#                                  InChICode_standardised  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1408  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1409  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1410  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1411  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1412  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#                              Standardized_SMILES_chembl  \
# 0                      COC(=O)Nc1nc2ccc(SC(C)C)cc2[nH]1
# 1                COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 2                 Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 3     CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 4                               CC1=NN(c2ccccc2)C(=O)C1
# ...                                                 ...
# 1408                         CCn1c(O)nc2cc(Cl)c(Cl)cc21
# 1409                              Cc1nc(O)c2cccc(O)c2n1
# 1410                        N=C(N)NC(=O)Cc1c(Cl)cccc1Cl
# 1411                       Nc1ccc(S(=O)(=O)Nc2nccs2)cc1
# 1412                        Cc1no[nH]c1=NC(=O)Nc1cccnc1
#
#                               Standardized_InChI_chembl  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1408  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1409  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1410  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1411  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1412  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#      Standardized_InChIKey_chembl      ChEMBL_ID  CHEMBL1741321  \
# 0     SXJIZQPZESTWLD-UHFFFAOYSA-N  CHEMBL1354363            0.0
# 1     NBLBCGUCPBXKOV-UHFFFAOYSA-N   CHEMBL307639            0.0
# 2     COBBNRKBTCBWQP-UHFFFAOYSA-N  CHEMBL1371756            1.0
# 3     GUGOEEXESWIERI-UHFFFAOYSA-N    CHEMBL17157            NaN
# 4     QELUYTUMUWHWMC-UHFFFAOYSA-N   CHEMBL290916            0.0
# ...                           ...            ...            ...
# 1408  LKHRMULASXZCLG-UHFFFAOYSA-N  CHEMBL1255655            NaN
# 1409  YJDAOHJWLUNFLX-UHFFFAOYSA-N   CHEMBL123904            1.0
# 1410  INJOMKTZOLKMBF-UHFFFAOYSA-N      CHEMBL862            0.0
# 1411  JNMRHUJNCSQMMB-UHFFFAOYSA-N      CHEMBL437            0.0
# 1412  NXRCDGIGKSHKAP-UHFFFAOYSA-N  CHEMBL1710820            0.0
#
#       CHEMBL1741322  CHEMBL1741323  CHEMBL1741324  CHEMBL1741325  ...  \
# 0               1.0            NaN            0.0            0.0  ...
# 1               1.0            0.0            NaN            0.0  ...
# 2               1.0            NaN            1.0            0.0  ...
# 3               NaN            NaN            NaN            NaN  ...
# 4               1.0            0.0            NaN            0.0  ...
# ...             ...            ...            ...            ...  ...
# 1408            1.0            0.0            1.0            0.0  ...
# 1409            1.0            1.0            0.0            1.0  ...
# 1410            0.0            0.0            0.0            NaN  ...
# 1411            0.0            0.0            0.0            NaN  ...
# 1412            1.0            0.0            0.0            0.0  ...
#
#       CHEMBL5291732  CHEMBL5291781  CHEMBL5291782  CHEMBL5291809  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               0.0            NaN            0.0            1.0
# 4               NaN            NaN            0.0            NaN
# ...             ...            ...            ...            ...
# 1408            NaN            NaN            NaN            NaN
# 1409            NaN            NaN            NaN            NaN
# 1410            0.0            NaN            NaN            NaN
# 1411            0.0            NaN            NaN            NaN
# 1412            NaN            NaN            NaN            NaN
#
#       CHEMBL5291815  CHEMBL5291818  CHEMBL5291822  CHEMBL5291850  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               0.0            0.0            0.0            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 1408            NaN            NaN            NaN            NaN
# 1409            NaN            NaN            NaN            NaN
# 1410            NaN            0.0            0.0            NaN
# 1411            NaN            NaN            NaN            NaN
# 1412            NaN            NaN            NaN            NaN
#
#       CHEMBL5291892  CHEMBL5291899
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            0.0
# 4               NaN            NaN
# ...             ...            ...
# 1408            NaN            NaN
# 1409            NaN            NaN
# 1410            NaN            0.0
# 1411            0.0            NaN
# 1412            NaN            NaN
#
# [1413 rows x 28 columns]

# %%
for col in filtered_df.columns[6:]:
    print(filtered_df[col].value_counts())
# Out:
# 1.0    429
# 0.0    342
# Name: CHEMBL1741322, dtype: int64
# 0.0    510
# 1.0    340
# Name: CHEMBL1741323, dtype: int64
# 0.0    506
# 1.0    277
# Name: CHEMBL1741324, dtype: int64
# 0.0    544
# 1.0    262
# Name: CHEMBL1741325, dtype: int64
# 0.0    342
# 1.0     23
# Name: CHEMBL1909087, dtype: int64
# 0.0    343
# 1.0     22
# Name: CHEMBL1909089, dtype: int64
# 0.0    339
# 1.0     26
# Name: CHEMBL1909104, dtype: int64
# 0.0    340
# 1.0     25
# Name: CHEMBL1909105, dtype: int64
# 0.0    338
# 1.0     27
# Name: CHEMBL1909141, dtype: int64
# 0.0    343
# 1.0     22
# Name: CHEMBL1909156, dtype: int64
# 0.0    337
# 1.0     28
# Name: CHEMBL1909211, dtype: int64
# 0.0    46
# 1.0    21
# Name: CHEMBL5291731, dtype: int64
# 0.0    71
# 1.0    36
# Name: CHEMBL5291732, dtype: int64
# 0.0    55
# 1.0    29
# Name: CHEMBL5291781, dtype: int64
# 0.0    48
# 1.0    30
# Name: CHEMBL5291782, dtype: int64
# 0.0    54
# 1.0    39
# Name: CHEMBL5291809, dtype: int64
# 0.0    56
# 1.0    21
# Name: CHEMBL5291815, dtype: int64
# 0.0    49
# 1.0    36
# Name: CHEMBL5291818, dtype: int64
# 0.0    38
# 1.0    31
# Name: CHEMBL5291822, dtype: int64
# 0.0    23
# 1.0    22
# Name: CHEMBL5291850, dtype: int64
# 0.0    70
# 1.0    23
# Name: CHEMBL5291892, dtype: int64
# 0.0    72
# 1.0    31
# Name: CHEMBL5291899, dtype: int64

# %%
CP = pd.read_csv("../Cell_Painting_Median_Features_Median_doses.csv")

# %%
import pandas as pd
from rdkit import Chem
from pandarallel import pandarallel

# Initialize pandarallel
pandarallel.initialize()

# Function to convert InChI to InChIKey
def inchi_to_inchikey(inchi):
    mol = Chem.inchi.MolFromInchi(inchi)
    if mol is not None:
        return Chem.MolToInchiKey(mol)
    else:
        return None
    
# Apply the function to the dataframe in parallel
CP['InChIKey'] = CP['InChICode_standardised'].parallel_apply(inchi_to_inchikey)

CP
# Out:
# INFO: Pandarallel will run on 40 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# [16:24:50] WARNING: not removing hydrogen atom without neighbors
# [16:24:50] WARNING: not removing hydrogen atom without neighbors
#                                   InChICode_standardised    index  \
# 0      InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...    960.0
# 1      InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...   1036.0
# 2      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4942.5
# 3      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4944.5
# 4      InChI=1S/C16H29N5O3/c1-12-9-20(13(2)10-22)16(2...   4949.5
# ...                                                  ...      ...
# 30399  InChI=1S/C9H9N5OS2/c10-12-8(16)11-6-3-1-2-5(4-...  30588.0
# 30400  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...  30589.0
# 30401  InChI=1S/C9H9NO2/c10-8-3-1-2-7(6-8)4-5-9(11)12...  30590.0
# 30402  InChI=1S/C9H9NO3S/c1-6(11)5-14-8-3-2-7(4-10-8)...  30591.0
# 30403  InChI=1S/C9H9NO5/c1-14-8-3-6(5-11)7(10(12)13)4...  30592.0
#
#        Metadata_mmoles_per_liter  Cells_AreaShape_Area  \
# 0                       5.000000           1728.953125
# 1                       5.000000           -272.074219
# 2                       4.973595            101.958984
# 3                       4.912934           -109.708984
# 4                       5.012874           -234.222656
# ...                          ...                   ...
# 30399                   5.000000           -226.027344
# 30400                   5.000000            254.769531
# 30401                   5.000000            238.574219
# 30402                   5.000000           -238.945312
# 30403                   5.000000            286.488281
#
#        Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0                     -1.375000                -25.445312
# 1                     11.464844                 -1.628906
# 2                     15.673828                 -2.314453
# 3                    -10.203125                  1.718750
# 4                      8.873047                  3.308594
# ...                         ...                       ...
# 30399                -18.847656                 -0.511719
# 30400                 18.886719                 -3.589844
# 30401                 -0.699219                  6.625000
# 30402                  5.476562                  0.089844
# 30403                  0.589844                 -3.125000
#
#        Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                        -0.067918                     -0.062396
# 1                        -0.001808                     -0.006674
# 2                         0.010687                      0.013397
# 3                         0.025025                      0.014627
# 4                         0.010192                      0.005251
# ...                            ...                           ...
# 30399                    -0.005827                      0.004864
# 30400                     0.027814                      0.016943
# 30401                     0.005228                      0.008800
# 30402                     0.018032                      0.012711
# 30403                     0.018058                      0.007385
#
#        Cells_AreaShape_EulerNumber  Cells_AreaShape_Extent  ...  \
# 0                              0.0                0.026443  ...
# 1                              0.0               -0.001405  ...
# 2                              0.0               -0.003746  ...
# 3                              0.0               -0.007164  ...
# 4                              0.0               -0.003173  ...
# ...                            ...                     ...  ...
# 30399                          0.0                0.003590  ...
# 30400                          0.0               -0.000781  ...
# 30401                          0.0                0.002336  ...
# 30402                          0.0               -0.004635  ...
# 30403                          0.0               -0.002819  ...
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_3_0  \
# 0                             0.314918                        0.222859
# 1                             0.023860                       -0.016903
# 2                            -0.014119                        0.035703
# 3                             0.046218                        0.031759
# 4                            -0.072889                       -0.030955
# ...                                ...                             ...
# 30399                        -0.114357                       -0.123664
# 30400                        -0.079942                       -0.018155
# 30401                        -0.107812                       -0.107077
# 30402                        -0.070647                       -0.095379
# 30403                        -0.035772                       -0.069146
#
#        Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                            0.280258                           0.192997
# 1                           -0.017773                          -0.028029
# 2                            0.016875                          -0.039304
# 3                            0.037029                          -0.051411
# 4                           -0.037623                          -0.009460
# ...                               ...                                ...
# 30399                       -0.127474                          -0.069665
# 30400                       -0.017759                          -0.118369
# 30401                       -0.138399                           0.168811
# 30402                       -0.102060                           0.023423
# 30403                       -0.038609                          -0.023672
#
#        Nuclei_Texture_Variance_Mito_3_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                              0.144917                          0.168085
# 1                             -0.038308                         -0.041455
# 2                             -0.070028                         -0.062892
# 3                             -0.083061                         -0.071562
# 4                              0.004604                         -0.010465
# ...                                 ...                               ...
# 30399                         -0.056972                         -0.044186
# 30400                         -0.046322                         -0.023926
# 30401                          0.216703                          0.195851
# 30402                          0.049321                          0.041996
# 30403                         -0.021189                         -0.042713
#
#        Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_3_0  \
# 0                             -0.332871                        -0.314733
# 1                             -0.070389                        -0.067789
# 2                             -0.015647                        -0.038908
# 3                             -0.024598                        -0.052021
# 4                             -0.031869                        -0.025910
# ...                                 ...                              ...
# 30399                         -0.019668                        -0.091541
# 30400                          0.033498                         0.051214
# 30401                         -0.063656                        -0.042877
# 30402                          0.023470                         0.058959
# 30403                          0.020877                         0.020216
#
#        Nuclei_Texture_Variance_RNA_5_0                     InChIKey
# 0                            -0.313477  SXJIZQPZESTWLD-UHFFFAOYSA-N
# 1                            -0.071673  NBLBCGUCPBXKOV-UHFFFAOYSA-N
# 2                            -0.026464  FOLOUAULJSJVDY-GZBFAFLISA-N
# 3                            -0.043327  FOLOUAULJSJVDY-IPYPFGDCSA-N
# 4                            -0.014907  FOLOUAULJSJVDY-NFAWXSAZSA-N
# ...                                ...                          ...
# 30399                        -0.062515  LHXWPDUWZAYBJV-UHFFFAOYSA-N
# 30400                         0.016060  IVYPNXXAYMYVSP-UHFFFAOYSA-N
# 30401                        -0.071681  JNXMJSYJCFTLJB-SNAWJCMRSA-N
# 30402                         0.065934  LRBIKSYRCFHKBN-UHFFFAOYSA-N
# 30403                         0.045447  YWSPWKXREVSQCA-UHFFFAOYSA-N
#
# [30404 rows x 1787 columns]

# %%
CP_new = CP[['Cells_Number_Object_Number',
             'Cells_Neighbors_FirstClosestObjectNumber_5',
 'Cells_Neighbors_FirstClosestObjectNumber_Adjacent',
 'Cells_Neighbors_SecondClosestObjectNumber_5',
 'Cells_Neighbors_SecondClosestObjectNumber_Adjacent',
 'Cells_Parent_Nuclei',
 'Cytoplasm_Number_Object_Number',
 'Cytoplasm_Parent_Cells',
 'Cytoplasm_Parent_Nuclei',
 'Nuclei_Neighbors_FirstClosestObjectNumber_1',
 'Nuclei_Neighbors_SecondClosestObjectNumber_1',
 'Nuclei_Number_Object_Number',
 "InChIKey"]]
CP_new
# Out:
#        Cells_Number_Object_Number  Cells_Neighbors_FirstClosestObjectNumber_5  \
# 0                      -26.265625                                  -26.218750
# 1                        4.812500                                    4.960938
# 2                       -2.435547                                   -2.722656
# 3                        0.964844                                    1.183594
# 4                        2.212891                                    2.699219
# ...                           ...                                         ...
# 30399                    2.714844                                    3.257812
# 30400                  -10.828125                                  -10.828125
# 30401                   -0.078125                                   -1.109375
# 30402                   -0.078125                                   -0.722656
# 30403                   -6.304688                                   -6.335938
#
#        Cells_Neighbors_FirstClosestObjectNumber_Adjacent  \
# 0                                             -26.218750
# 1                                               4.960938
# 2                                              -2.722656
# 3                                               1.183594
# 4                                               2.699219
# ...                                                  ...
# 30399                                           3.257812
# 30400                                         -10.828125
# 30401                                          -1.109375
# 30402                                          -0.722656
# 30403                                          -6.335938
#
#        Cells_Neighbors_SecondClosestObjectNumber_5  \
# 0                                       -27.265625
# 1                                         5.843750
# 2                                        -2.509766
# 3                                         0.726562
# 4                                         2.539062
# ...                                            ...
# 30399                                     3.324219
# 30400                                    -9.937500
# 30401                                     0.382812
# 30402                                    -0.015625
# 30403                                    -5.835938
#
#        Cells_Neighbors_SecondClosestObjectNumber_Adjacent  \
# 0                                             -27.265625
# 1                                               5.843750
# 2                                              -2.509766
# 3                                               0.726562
# 4                                               2.539062
# ...                                                  ...
# 30399                                           3.324219
# 30400                                          -9.937500
# 30401                                           0.382812
# 30402                                          -0.015625
# 30403                                          -5.835938
#
#        Cells_Parent_Nuclei  Cytoplasm_Number_Object_Number  \
# 0               -26.265625                      -26.265625
# 1                 4.828125                        4.812500
# 2                -2.435547                       -2.435547
# 3                 0.968750                        0.964844
# 4                 2.216797                        2.212891
# ...                    ...                             ...
# 30399             2.714844                        2.714844
# 30400           -10.828125                      -10.828125
# 30401            -0.078125                       -0.078125
# 30402            -0.078125                       -0.078125
# 30403            -6.304688                       -6.304688
#
#        Cytoplasm_Parent_Cells  Cytoplasm_Parent_Nuclei  \
# 0                  -26.265625               -26.265625
# 1                    4.828125                 4.828125
# 2                   -2.435547                -2.435547
# 3                    0.968750                 0.968750
# 4                    2.216797                 2.216797
# ...                       ...                      ...
# 30399                2.714844                 2.714844
# 30400              -10.828125               -10.828125
# 30401               -0.078125                -0.078125
# 30402               -0.078125                -0.078125
# 30403               -6.304688                -6.304688
#
#        Nuclei_Neighbors_FirstClosestObjectNumber_1  \
# 0                                       -26.187500
# 1                                         4.726562
# 2                                        -2.449219
# 3                                         1.228516
# 4                                         3.253906
# ...                                            ...
# 30399                                     3.773438
# 30400                                   -10.679688
# 30401                                    -0.132812
# 30402                                    -0.398438
# 30403                                    -5.968750
#
#        Nuclei_Neighbors_SecondClosestObjectNumber_1  \
# 0                                        -26.218750
# 1                                          4.718750
# 2                                         -2.455078
# 3                                          0.324219
# 4                                          2.826172
# ...                                             ...
# 30399                                      2.773438
# 30400                                    -10.460938
# 30401                                     -1.000000
# 30402                                      0.101562
# 30403                                     -6.257812
#
#        Nuclei_Number_Object_Number                     InChIKey
# 0                       -26.265625  SXJIZQPZESTWLD-UHFFFAOYSA-N
# 1                         4.812500  NBLBCGUCPBXKOV-UHFFFAOYSA-N
# 2                        -2.435547  FOLOUAULJSJVDY-GZBFAFLISA-N
# 3                         0.964844  FOLOUAULJSJVDY-IPYPFGDCSA-N
# 4                         2.212891  FOLOUAULJSJVDY-NFAWXSAZSA-N
# ...                            ...                          ...
# 30399                     2.714844  LHXWPDUWZAYBJV-UHFFFAOYSA-N
# 30400                   -10.828125  IVYPNXXAYMYVSP-UHFFFAOYSA-N
# 30401                    -0.078125  JNXMJSYJCFTLJB-SNAWJCMRSA-N
# 30402                    -0.078125  LRBIKSYRCFHKBN-UHFFFAOYSA-N
# 30403                    -6.304688  YWSPWKXREVSQCA-UHFFFAOYSA-N
#
# [30404 rows x 13 columns]

# %%
k = pd.merge(filtered_df ,CP_new, left_on="Standardized_InChIKey_chembl", right_on="InChIKey", how="inner").reset_index(drop=True)
k
# Out:
#                                  InChICode_standardised  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1407  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1408  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1409  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1410  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1411  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#                              Standardized_SMILES_chembl  \
# 0                      COC(=O)Nc1nc2ccc(SC(C)C)cc2[nH]1
# 1                COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 2                 Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 3     CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 4                               CC1=NN(c2ccccc2)C(=O)C1
# ...                                                 ...
# 1407                         CCn1c(O)nc2cc(Cl)c(Cl)cc21
# 1408                              Cc1nc(O)c2cccc(O)c2n1
# 1409                        N=C(N)NC(=O)Cc1c(Cl)cccc1Cl
# 1410                       Nc1ccc(S(=O)(=O)Nc2nccs2)cc1
# 1411                        Cc1no[nH]c1=NC(=O)Nc1cccnc1
#
#                               Standardized_InChI_chembl  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1407  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1408  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1409  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1410  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1411  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#      Standardized_InChIKey_chembl      ChEMBL_ID  CHEMBL1741321  \
# 0     SXJIZQPZESTWLD-UHFFFAOYSA-N  CHEMBL1354363            0.0
# 1     NBLBCGUCPBXKOV-UHFFFAOYSA-N   CHEMBL307639            0.0
# 2     COBBNRKBTCBWQP-UHFFFAOYSA-N  CHEMBL1371756            1.0
# 3     GUGOEEXESWIERI-UHFFFAOYSA-N    CHEMBL17157            NaN
# 4     QELUYTUMUWHWMC-UHFFFAOYSA-N   CHEMBL290916            0.0
# ...                           ...            ...            ...
# 1407  LKHRMULASXZCLG-UHFFFAOYSA-N  CHEMBL1255655            NaN
# 1408  YJDAOHJWLUNFLX-UHFFFAOYSA-N   CHEMBL123904            1.0
# 1409  INJOMKTZOLKMBF-UHFFFAOYSA-N      CHEMBL862            0.0
# 1410  JNMRHUJNCSQMMB-UHFFFAOYSA-N      CHEMBL437            0.0
# 1411  NXRCDGIGKSHKAP-UHFFFAOYSA-N  CHEMBL1710820            0.0
#
#       CHEMBL1741322  CHEMBL1741323  CHEMBL1741324  CHEMBL1741325  ...  \
# 0               1.0            NaN            0.0            0.0  ...
# 1               1.0            0.0            NaN            0.0  ...
# 2               1.0            NaN            1.0            0.0  ...
# 3               NaN            NaN            NaN            NaN  ...
# 4               1.0            0.0            NaN            0.0  ...
# ...             ...            ...            ...            ...  ...
# 1407            1.0            0.0            1.0            0.0  ...
# 1408            1.0            1.0            0.0            1.0  ...
# 1409            0.0            0.0            0.0            NaN  ...
# 1410            0.0            0.0            0.0            NaN  ...
# 1411            1.0            0.0            0.0            0.0  ...
#
#       Cells_Neighbors_SecondClosestObjectNumber_5  \
# 0                                      -27.265625
# 1                                        5.843750
# 2                                        5.906250
# 3                                      -25.511719
# 4                                       -1.593750
# ...                                           ...
# 1407                                    -4.953125
# 1408                                     5.976562
# 1409                                     3.132812
# 1410                                    -3.906250
# 1411                                     5.226562
#
#       Cells_Neighbors_SecondClosestObjectNumber_Adjacent  Cells_Parent_Nuclei  \
# 0                                            -27.265625            -26.265625
# 1                                              5.843750              4.828125
# 2                                              5.906250              6.000000
# 3                                            -25.511719            -24.691406
# 4                                             -1.593750             -1.117188
# ...                                                 ...                   ...
# 1407                                          -4.953125             -4.914062
# 1408                                           5.976562              5.351562
# 1409                                           3.132812              2.585938
# 1410                                          -3.906250             -4.046875
# 1411                                           5.226562              5.234375
#
#       Cytoplasm_Number_Object_Number  Cytoplasm_Parent_Cells  \
# 0                         -26.265625              -26.265625
# 1                           4.812500                4.828125
# 2                           6.000000                6.000000
# 3                         -24.691406              -24.691406
# 4                          -1.117188               -1.117188
# ...                              ...                     ...
# 1407                       -4.914062               -4.914062
# 1408                        5.351562                5.351562
# 1409                        2.585938                2.585938
# 1410                       -4.046875               -4.046875
# 1411                        5.234375                5.234375
#
#       Cytoplasm_Parent_Nuclei  Nuclei_Neighbors_FirstClosestObjectNumber_1  \
# 0                  -26.265625                                   -26.187500
# 1                    4.828125                                     4.726562
# 2                    6.000000                                     5.570312
# 3                  -24.691406                                   -25.625000
# 4                   -1.117188                                    -0.664062
# ...                       ...                                          ...
# 1407                -4.914062                                    -5.492188
# 1408                 5.351562                                     5.437500
# 1409                 2.585938                                     2.625000
# 1410                -4.046875                                    -4.031250
# 1411                 5.234375                                     6.281250
#
#       Nuclei_Neighbors_SecondClosestObjectNumber_1  \
# 0                                       -26.218750
# 1                                         4.718750
# 2                                         5.992188
# 3                                       -25.523438
# 4                                        -1.203125
# ...                                            ...
# 1407                                     -4.382812
# 1408                                      4.812500
# 1409                                      3.304688
# 1410                                     -3.890625
# 1411                                      5.382812
#
#       Nuclei_Number_Object_Number                     InChIKey
# 0                      -26.265625  SXJIZQPZESTWLD-UHFFFAOYSA-N
# 1                        4.812500  NBLBCGUCPBXKOV-UHFFFAOYSA-N
# 2                        6.000000  COBBNRKBTCBWQP-UHFFFAOYSA-N
# 3                      -24.691406  GUGOEEXESWIERI-UHFFFAOYSA-N
# 4                       -1.117188  QELUYTUMUWHWMC-UHFFFAOYSA-N
# ...                           ...                          ...
# 1407                    -4.914062  LKHRMULASXZCLG-UHFFFAOYSA-N
# 1408                     5.351562  YJDAOHJWLUNFLX-UHFFFAOYSA-N
# 1409                     2.585938  INJOMKTZOLKMBF-UHFFFAOYSA-N
# 1410                    -4.046875  JNMRHUJNCSQMMB-UHFFFAOYSA-N
# 1411                     5.234375  NXRCDGIGKSHKAP-UHFFFAOYSA-N
#
# [1412 rows x 41 columns]

# %%
k.to_csv("CP_count_Seal.csv", index=False)

# %%
import pandas as pd

# %%
# Drop the 'InChIKey' column as it is not part of the target data
df_targets = filtered_df.drop(columns=["InChICode_standardised","Standardized_SMILES_chembl",
                              "Standardized_InChI_chembl",
                              "Standardized_InChIKey_chembl","ChEMBL_ID"])

# Calculate the total number of cells in the DataFrame
total_cells = df_targets.size

# Calculate the number of cells that have nan
cells_with_nan = (df_targets.isna()).sum().sum()

# Calculate the percentage of cells that have nan
percentage_nan = (cells_with_nan / total_cells) * 100

pos = (df_targets==1).sum().sum()
neg = (df_targets==0).sum().sum()
percentage_positive = (pos / (pos + neg)) * 100

# Print the results
print(f"Total number of cells: {total_cells}")
print(f"Number of cells with no data: {cells_with_nan}")
print(f"Percentage of cells with no data: {percentage_nan:.2f}%")
print(f"Percentage of actives: {percentage_positive:.2f}%")
# Out:
# Total number of cells: 32499
# Number of cells with no data: 24986
# Percentage of cells with no data: 76.88%
# Percentage of actives: 27.05%

# %%
j = pd.merge(filtered_df ,CP, left_on="Standardized_InChIKey_chembl", right_on="InChIKey", how="inner").reset_index(drop=True)
j
# Out:
#                                InChICode_standardised_x  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1407  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1408  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1409  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1410  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1411  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#                              Standardized_SMILES_chembl  \
# 0                      COC(=O)Nc1nc2ccc(SC(C)C)cc2[nH]1
# 1                COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 2                 Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 3     CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 4                               CC1=NN(c2ccccc2)C(=O)C1
# ...                                                 ...
# 1407                         CCn1c(O)nc2cc(Cl)c(Cl)cc21
# 1408                              Cc1nc(O)c2cccc(O)c2n1
# 1409                        N=C(N)NC(=O)Cc1c(Cl)cccc1Cl
# 1410                       Nc1ccc(S(=O)(=O)Nc2nccs2)cc1
# 1411                        Cc1no[nH]c1=NC(=O)Nc1cccnc1
#
#                               Standardized_InChI_chembl  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1407  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1408  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1409  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1410  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1411  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#      Standardized_InChIKey_chembl      ChEMBL_ID  CHEMBL1741321  \
# 0     SXJIZQPZESTWLD-UHFFFAOYSA-N  CHEMBL1354363            0.0
# 1     NBLBCGUCPBXKOV-UHFFFAOYSA-N   CHEMBL307639            0.0
# 2     COBBNRKBTCBWQP-UHFFFAOYSA-N  CHEMBL1371756            1.0
# 3     GUGOEEXESWIERI-UHFFFAOYSA-N    CHEMBL17157            NaN
# 4     QELUYTUMUWHWMC-UHFFFAOYSA-N   CHEMBL290916            0.0
# ...                           ...            ...            ...
# 1407  LKHRMULASXZCLG-UHFFFAOYSA-N  CHEMBL1255655            NaN
# 1408  YJDAOHJWLUNFLX-UHFFFAOYSA-N   CHEMBL123904            1.0
# 1409  INJOMKTZOLKMBF-UHFFFAOYSA-N      CHEMBL862            0.0
# 1410  JNMRHUJNCSQMMB-UHFFFAOYSA-N      CHEMBL437            0.0
# 1411  NXRCDGIGKSHKAP-UHFFFAOYSA-N  CHEMBL1710820            0.0
#
#       CHEMBL1741322  CHEMBL1741323  CHEMBL1741324  CHEMBL1741325  ...  \
# 0               1.0            NaN            0.0            0.0  ...
# 1               1.0            0.0            NaN            0.0  ...
# 2               1.0            NaN            1.0            0.0  ...
# 3               NaN            NaN            NaN            NaN  ...
# 4               1.0            0.0            NaN            0.0  ...
# ...             ...            ...            ...            ...  ...
# 1407            1.0            0.0            1.0            0.0  ...
# 1408            1.0            1.0            0.0            1.0  ...
# 1409            0.0            0.0            0.0            NaN  ...
# 1410            0.0            0.0            0.0            NaN  ...
# 1411            1.0            0.0            0.0            0.0  ...
#
#       Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_3_0  \
# 0                            0.314918                        0.222859
# 1                            0.023860                       -0.016903
# 2                            0.052843                       -0.004288
# 3                            0.813737                        1.745136
# 4                           -0.059237                       -0.073432
# ...                               ...                             ...
# 1407                        -0.075060                       -0.082801
# 1408                        -0.058793                        0.027084
# 1409                        -0.046451                        0.001106
# 1410                         0.017906                       -0.026654
# 1411                        -0.099494                       -0.146276
#
#       Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                           0.280258                           0.192997
# 1                          -0.017773                          -0.028029
# 2                           0.025918                           0.020560
# 3                           1.483225                           0.531463
# 4                          -0.070867                          -0.037841
# ...                              ...                                ...
# 1407                       -0.096520                          -0.166819
# 1408                        0.010825                          -0.011973
# 1409                        0.007827                           0.004506
# 1410                       -0.007774                          -0.088286
# 1411                       -0.152421                          -0.096443
#
#       Nuclei_Texture_Variance_Mito_3_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                             0.144917                          0.168085
# 1                            -0.038308                         -0.041455
# 2                             0.004302                         -0.008033
# 3                             1.579915                          1.493236
# 4                            -0.081784                         -0.085790
# ...                                ...                               ...
# 1407                         -0.222268                         -0.208941
# 1408                         -0.033669                         -0.017549
# 1409                         -0.029183                         -0.005974
# 1410                         -0.052080                         -0.073599
# 1411                         -0.110563                         -0.126393
#
#       Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_3_0  \
# 0                            -0.332871                        -0.314733
# 1                            -0.070389                        -0.067789
# 2                            -0.056396                        -0.026962
# 3                            -0.703972                         0.540142
# 4                            -0.083668                        -0.064161
# ...                                ...                              ...
# 1407                         -0.008082                        -0.021377
# 1408                         -0.070822                        -0.041223
# 1409                         -0.077268                        -0.073622
# 1410                         -0.055808                        -0.070133
# 1411                         -0.048527                        -0.044408
#
#       Nuclei_Texture_Variance_RNA_5_0                     InChIKey
# 0                           -0.313477  SXJIZQPZESTWLD-UHFFFAOYSA-N
# 1                           -0.071673  NBLBCGUCPBXKOV-UHFFFAOYSA-N
# 2                           -0.039564  COBBNRKBTCBWQP-UHFFFAOYSA-N
# 3                            0.358874  GUGOEEXESWIERI-UHFFFAOYSA-N
# 4                           -0.074736  QELUYTUMUWHWMC-UHFFFAOYSA-N
# ...                               ...                          ...
# 1407                        -0.017203  LKHRMULASXZCLG-UHFFFAOYSA-N
# 1408                        -0.046780  YJDAOHJWLUNFLX-UHFFFAOYSA-N
# 1409                        -0.056681  INJOMKTZOLKMBF-UHFFFAOYSA-N
# 1410                        -0.061253  JNMRHUJNCSQMMB-UHFFFAOYSA-N
# 1411                        -0.064477  NXRCDGIGKSHKAP-UHFFFAOYSA-N
#
# [1412 rows x 1815 columns]

# %%
j.to_csv("CP_all_Seal.csv", index=False)
