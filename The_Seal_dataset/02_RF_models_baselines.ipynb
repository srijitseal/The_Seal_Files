# %%
import pandas as pd

data = pd.read_csv("CP_all_Seal.csv")
data
# Out:
#                                InChICode_standardised_x  \
# 0     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 1     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 2     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# 3     InChI=1S/C10H10N4O2/c15-10(16)6-9(14-7-11-12-1...
# 4     InChI=1S/C10H10N4O2S/c11-8-2-4-9(5-3-8)17(15,1...
# ...                                                 ...
# 1344  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1345  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1346  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1347  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1348  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#                   Standardized_SMILES_chembl  \
# 0     COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 1      Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 2                    CC1=NN(c2ccccc2)C(=O)C1
# 3                  O=C(O)CC(c1ccccc1)n1cnnn1
# 4              Nc1ccc(S(=O)(=O)Nc2ncccn2)cc1
# ...                                      ...
# 1344              CCn1c(O)nc2cc(Cl)c(Cl)cc21
# 1345                   Cc1nc(O)c2cccc(O)c2n1
# 1346             N=C(N)NC(=O)Cc1c(Cl)cccc1Cl
# 1347            Nc1ccc(S(=O)(=O)Nc2nccs2)cc1
# 1348             Cc1no[nH]c1=NC(=O)Nc1cccnc1
#
#                               Standardized_InChI_chembl  \
# 0     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 1     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 2     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# 3     InChI=1S/C10H10N4O2/c15-10(16)6-9(14-7-11-12-1...
# 4     InChI=1S/C10H10N4O2S/c11-8-2-4-9(5-3-8)17(15,1...
# ...                                                 ...
# 1344  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1345  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1346  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1347  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1348  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#      Standardized_InChIKey_chembl      ChEMBL_ID  CHEMBL1741321  \
# 0     NBLBCGUCPBXKOV-UHFFFAOYSA-N   CHEMBL307639            0.0
# 1     COBBNRKBTCBWQP-UHFFFAOYSA-N  CHEMBL1371756            1.0
# 2     QELUYTUMUWHWMC-UHFFFAOYSA-N   CHEMBL290916            0.0
# 3     IPEATIREFBKQKS-UHFFFAOYSA-N  CHEMBL1351012            0.0
# 4     SEEPANYCNGTZFQ-UHFFFAOYSA-N      CHEMBL439            0.0
# ...                           ...            ...            ...
# 1344  LKHRMULASXZCLG-UHFFFAOYSA-N  CHEMBL1255655            NaN
# 1345  YJDAOHJWLUNFLX-UHFFFAOYSA-N   CHEMBL123904            1.0
# 1346  INJOMKTZOLKMBF-UHFFFAOYSA-N      CHEMBL862            0.0
# 1347  JNMRHUJNCSQMMB-UHFFFAOYSA-N      CHEMBL437            0.0
# 1348  NXRCDGIGKSHKAP-UHFFFAOYSA-N  CHEMBL1710820            0.0
#
#       CHEMBL1741322  CHEMBL1741323  CHEMBL1741324  CHEMBL1741325  ...  \
# 0               1.0            0.0            NaN            0.0  ...
# 1               1.0            NaN            1.0            0.0  ...
# 2               1.0            0.0            NaN            0.0  ...
# 3               0.0            0.0            0.0            0.0  ...
# 4               0.0            0.0            0.0            0.0  ...
# ...             ...            ...            ...            ...  ...
# 1344            1.0            0.0            1.0            0.0  ...
# 1345            1.0            1.0            0.0            1.0  ...
# 1346            0.0            0.0            0.0            NaN  ...
# 1347            0.0            0.0            0.0            NaN  ...
# 1348            1.0            0.0            0.0            0.0  ...
#
#       Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_3_0  \
# 0                            0.023860                       -0.016903
# 1                            0.052843                       -0.004288
# 2                           -0.059237                       -0.073432
# 3                           -0.048975                       -0.093494
# 4                           -0.048030                       -0.110928
# ...                               ...                             ...
# 1344                        -0.075060                       -0.082801
# 1345                        -0.058793                        0.027084
# 1346                        -0.046451                        0.001106
# 1347                         0.017906                       -0.026654
# 1348                        -0.099494                       -0.146276
#
#       Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                          -0.017773                          -0.028029
# 1                           0.025918                           0.020560
# 2                          -0.070867                          -0.037841
# 3                          -0.064515                           0.174397
# 4                          -0.107340                           0.018558
# ...                              ...                                ...
# 1344                       -0.096520                          -0.166819
# 1345                        0.010825                          -0.011973
# 1346                        0.007827                           0.004506
# 1347                       -0.007774                          -0.088286
# 1348                       -0.152421                          -0.096443
#
#       Nuclei_Texture_Variance_Mito_3_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                            -0.038308                         -0.041455
# 1                             0.004302                         -0.008033
# 2                            -0.081784                         -0.085790
# 3                             0.177086                          0.170171
# 4                             0.028730                          0.039671
# ...                                ...                               ...
# 1344                         -0.222268                         -0.208941
# 1345                         -0.033669                         -0.017549
# 1346                         -0.029183                         -0.005974
# 1347                         -0.052080                         -0.073599
# 1348                         -0.110563                         -0.126393
#
#       Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_3_0  \
# 0                            -0.070389                        -0.067789
# 1                            -0.056396                        -0.026962
# 2                            -0.083668                        -0.064161
# 3                            -0.079487                        -0.081858
# 4                            -0.085405                        -0.065859
# ...                                ...                              ...
# 1344                         -0.008082                        -0.021377
# 1345                         -0.070822                        -0.041223
# 1346                         -0.077268                        -0.073622
# 1347                         -0.055808                        -0.070133
# 1348                         -0.048527                        -0.044408
#
#       Nuclei_Texture_Variance_RNA_5_0                     InChIKey
# 0                           -0.071673  NBLBCGUCPBXKOV-UHFFFAOYSA-N
# 1                           -0.039564  COBBNRKBTCBWQP-UHFFFAOYSA-N
# 2                           -0.074736  QELUYTUMUWHWMC-UHFFFAOYSA-N
# 3                           -0.070991  IPEATIREFBKQKS-UHFFFAOYSA-N
# 4                           -0.072910  SEEPANYCNGTZFQ-UHFFFAOYSA-N
# ...                               ...                          ...
# 1344                        -0.017203  LKHRMULASXZCLG-UHFFFAOYSA-N
# 1345                        -0.046780  YJDAOHJWLUNFLX-UHFFFAOYSA-N
# 1346                        -0.056681  INJOMKTZOLKMBF-UHFFFAOYSA-N
# 1347                        -0.061253  JNMRHUJNCSQMMB-UHFFFAOYSA-N
# 1348                        -0.064477  NXRCDGIGKSHKAP-UHFFFAOYSA-N
#
# [1349 rows x 1815 columns]

# %%
CellProfiler = data.columns.to_list()[31:-1]

# %%
assays_list = data.columns.to_list()[5:28]
len(assays_list)
assays_list
# Out:
# ['CHEMBL1741321',
#  'CHEMBL1741322',
#  'CHEMBL1741323',
#  'CHEMBL1741324',
#  'CHEMBL1741325',
#  'CHEMBL1909087',
#  'CHEMBL1909089',
#  'CHEMBL1909104',
#  'CHEMBL1909105',
#  'CHEMBL1909141',
#  'CHEMBL1909156',
#  'CHEMBL1909211',
#  'CHEMBL5291731',
#  'CHEMBL5291732',
#  'CHEMBL5291781',
#  'CHEMBL5291782',
#  'CHEMBL5291809',
#  'CHEMBL5291815',
#  'CHEMBL5291818',
#  'CHEMBL5291822',
#  'CHEMBL5291850',
#  'CHEMBL5291892',
#  'CHEMBL5291899']

# %%
len(assays_list)
# Out:
# 23

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
import pandas as pd
from tqdm import tqdm
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.model_selection import RandomizedSearchCV
import os

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    roc_auc_score,
    matthews_corrcoef,
    confusion_matrix,
    roc_curve,
    precision_recall_curve,
    auc,
    cohen_kappa_score
)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_predict, RandomizedSearchCV
from sklearn.utils import class_weight
import pandas as pd
from tqdm import tqdm
from sklearn.utils import shuffle

# Function to calculate metrics
def calculate_metrics(y_true, y_pred_proba, threshold=0.5):
    y_pred_opt = (y_pred_proba >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred_opt).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    balanced_accuracy = (sensitivity + specificity) / 2
    mcc = matthews_corrcoef(y_true, y_pred_opt)
    kappa = cohen_kappa_score(y_true, y_pred_opt)
    
    # AUCPR
    precision, recall, _ = precision_recall_curve(y_true, y_pred_proba)
    aucpr = auc(recall, precision)
    
    # Cohen's Kappa at threshold 0.50
    kappa_at_50 = cohen_kappa_score(y_true, (y_pred_proba >= 0.50).astype(int))
    
    return {
        "Threshold": threshold,
        "Balanced Accuracy": balanced_accuracy,
        "Sensitivity": sensitivity,
        "Specificity": specificity,
        "MCC": mcc,
        "AUCPR": aucpr,
        "Cohen's Kappa": kappa,
        "Cohen's Kappa @ 0.50": kappa_at_50,
        "Confusion Matrix": {"TN": tn, "FP": fp, "FN": fn, "TP": tp},
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
    }

# Function to find the best threshold based on Cohen's Kappa
def find_best_threshold_for_kappa(y_true, y_pred_proba):
    thresholds = np.linspace(0, 1, 100)
    best_kappa = -1
    best_threshold = 0.5
    for threshold in thresholds:
        y_pred = (y_pred_proba >= threshold).astype(int)
        kappa = cohen_kappa_score(y_true, y_pred)
        if kappa > best_kappa:
            best_kappa = kappa
            best_threshold = threshold
    return best_threshold, best_kappa

# Initialize results
all_auc_scores = []

# Stratified splitting setup
stratified_kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Define the two sets of features
feature_sets = {
    "CellCount": ["Cells_Number_Object_Number"],  # Feature set cell count
    "CellProfiler": CellProfiler  # Feature set CP
}

# Loop through each assay to create individual models
for assay in tqdm(assays_list):
    
    # Filter out rows with missing values for the current assay
    assay_data = data[~data[assay].isna()].reset_index(drop=True)
    print(assay_data[assay].value_counts())
    
    # Extract labels
    y = assay_data[assay].astype(int)

    # Check for class imbalance
    if len(np.unique(y)) < 2:
        print(f"Skipping assay {assay} due to lack of positive/negative classes")
        continue
    
    # Calculate class weights
    class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y), y=y)
    class_weight_dict = {0: class_weights[0], 1: class_weights[1]}
    
    rf_param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [5, 10, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'class_weight': ['balanced']
    }
    
    logreg_param_grid = {
        'C': [0.01, 0.1, 1, 10, 100],
        'penalty': ['l1', 'l2'],
        'solver': ['liblinear']
    }
    
    for feature_set_name, feature_columns in feature_sets.items():
        
        # Extract features for the current feature set
        X = assay_data[feature_columns]

        for fold, (train_idx, test_idx) in enumerate(stratified_kfold.split(X, y)):
            X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
            y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
                 
            # Determine the model type based on the number of features
            if len(feature_columns) == 1:
                # Use Logistic Regression
                model = LogisticRegression(class_weight='balanced', random_state=42)
                param_grid = logreg_param_grid
            else:
                # Use Random Forest
                model = RandomForestClassifier(random_state=42, n_jobs=-1)
                param_grid = rf_param_grid

            # Perform RandomizedSearchCV
            random_search = RandomizedSearchCV(
                estimator=model,
                param_distributions=param_grid,
                n_iter=10,
                scoring='roc_auc',
                cv=3,
                n_jobs=-1,
                verbose=2,
                random_state=42
            )
            random_search.fit(X_train, y_train)

            # Best model
            best_model = random_search.best_estimator_

            # Generate OOB predictions for training data
            oob_pred_proba = cross_val_predict(
                best_model,
                X_train,
                y_train,
                cv=stratified_kfold,
                method='predict_proba'
            )[:, 1]
            
            # Optimize threshold using Cohen's Kappa
            opt_threshold, best_kappa = find_best_threshold_for_kappa(y_train, oob_pred_proba)
            
            # Test set predictions
            y_pred_proba = best_model.predict_proba(X_test)[:, 1]
            test_metrics = calculate_metrics(y_test, y_pred_proba, threshold=opt_threshold)
            
            # Random Y-scrambling
            y_train_scrambled = shuffle(y_train, random_state=fold)
            best_model.fit(X_train, y_train_scrambled)
            y_pred_proba_scrambled = best_model.predict_proba(X_test)[:, 1]
            scrambled_metrics = calculate_metrics(y_test, y_pred_proba_scrambled, threshold=0.50)
            
            # Collect results
            all_auc_scores.append({
                "Feature Set": feature_set_name,
                "Fold": fold + 1,
                "Task": assay,
                "AUC": roc_auc_score(y_test, y_pred_proba),
                "Optimal Threshold": opt_threshold,
                "Optimal Kappa": best_kappa,
                "Kappa": test_metrics["Cohen's Kappa"],
                "Kappa @ 0.50": test_metrics["Cohen's Kappa @ 0.50"],
                "Balanced Accuracy": test_metrics["Balanced Accuracy"],
                "AUCPR": test_metrics["AUCPR"],
                "Sensitivity": test_metrics["Sensitivity"],
                "Specificity": test_metrics["Specificity"],
                "MCC": test_metrics["MCC"],
                "TP": test_metrics["TP"],
                "TN": test_metrics["TN"],
                "FP": test_metrics["FP"],
                "FN": test_metrics["FN"],
                "Total Actives Train": sum(y_train),
                "Total Inactives Train": len(y_train) - sum(y_train),
                "Total Compounds Train": len(y_train),
                "Total Actives Test": sum(y_test),
                "Total Inactives Test": len(y_test) - sum(y_test),
                "Total Compounds Test": len(y_test),
                "Scrambled Kappa": scrambled_metrics["Cohen's Kappa"],
                "Scrambled Balanced Accuracy": scrambled_metrics["Balanced Accuracy"],
            })
            print(f"Assay: {assay}, Fold: {fold + 1}, AUC: {roc_auc_score(y_test, y_pred_proba):.3f}")
            # Convert results to DataFrame and save
            auc_df = pd.DataFrame(all_auc_scores)
            auc_df.to_csv("auc_scores_with_rf_kappa_thresholding_detailed.csv", index=False)


# Convert results to DataFrame and save
auc_df = pd.DataFrame(all_auc_scores)
auc_df.to_csv("auc_scores_with_rf_kappa_thresholding_detailed.csv", index=False)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]
# 0.0    590
# 1.0    221
# Name: CHEMBL1741321, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 1, AUC: 0.651
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 2, AUC: 0.532
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 3, AUC: 0.667
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 1, AUC: 0.699
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 2, AUC: 0.576
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#   4%|▍         | 1/23 [00:18<06:37, 18.06s/it]
# Assay: CHEMBL1741321, Fold: 3, AUC: 0.687
# 1.0    400
# 0.0    336
# Name: CHEMBL1741322, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 2, AUC: 0.508
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 3, AUC: 0.470
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 1, AUC: 0.538
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 2, AUC: 0.600
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#   9%|▊         | 2/23 [00:31<05:18, 15.18s/it]
# Assay: CHEMBL1741322, Fold: 3, AUC: 0.599
# 0.0    486
# 1.0    330
# Name: CHEMBL1741323, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 1, AUC: 0.540
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 2, AUC: 0.572
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 3, AUC: 0.582
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 1, AUC: 0.818
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 2, AUC: 0.757
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  13%|█▎        | 3/23 [00:43<04:38, 13.92s/it]
# Assay: CHEMBL1741323, Fold: 3, AUC: 0.812
# 0.0    489
# 1.0    263
# Name: CHEMBL1741324, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 1, AUC: 0.524
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 2, AUC: 0.522
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 3, AUC: 0.550
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 1, AUC: 0.646
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 2, AUC: 0.694
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  17%|█▋        | 4/23 [00:57<04:21, 13.76s/it]
# Assay: CHEMBL1741324, Fold: 3, AUC: 0.689
# 0.0    515
# 1.0    252
# Name: CHEMBL1741325, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 1, AUC: 0.595
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 2, AUC: 0.626
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 3, AUC: 0.554
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 1, AUC: 0.777
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 2, AUC: 0.795
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  22%|██▏       | 5/23 [01:09<03:58, 13.27s/it]
# Assay: CHEMBL1741325, Fold: 3, AUC: 0.810
# 0.0    319
# 1.0     23
# Name: CHEMBL1909087, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 2, AUC: 0.597
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 3, AUC: 0.511
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 1, AUC: 0.812
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 2, AUC: 0.866
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  26%|██▌       | 6/23 [01:21<03:38, 12.83s/it]
# Assay: CHEMBL1909087, Fold: 3, AUC: 0.629
# 0.0    320
# 1.0     22
# Name: CHEMBL1909089, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 1, AUC: 0.482
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 2, AUC: 0.698
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 3, AUC: 0.633
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 1, AUC: 0.623
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 2, AUC: 0.685
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  30%|███       | 7/23 [01:33<03:21, 12.58s/it]
# Assay: CHEMBL1909089, Fold: 3, AUC: 0.748
# 0.0    317
# 1.0     25
# Name: CHEMBL1909104, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 1, AUC: 0.550
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 2, AUC: 0.509
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 1, AUC: 0.800
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 2, AUC: 0.627
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  35%|███▍      | 8/23 [01:46<03:11, 12.74s/it]
# Assay: CHEMBL1909104, Fold: 3, AUC: 0.870
# 0.0    317
# 1.0     25
# Name: CHEMBL1909105, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 1, AUC: 0.522
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 2, AUC: 0.661
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 3, AUC: 0.592
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 1, AUC: 0.830
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 2, AUC: 0.757
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  39%|███▉      | 9/23 [01:59<02:59, 12.79s/it]
# Assay: CHEMBL1909105, Fold: 3, AUC: 0.854
# 0.0    315
# 1.0     27
# Name: CHEMBL1909141, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 1, AUC: 0.502
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 1, AUC: 0.793
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 2, AUC: 0.792
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  43%|████▎     | 10/23 [02:11<02:43, 12.60s/it]
# Assay: CHEMBL1909141, Fold: 3, AUC: 0.650
# 0.0    321
# 1.0     21
# Name: CHEMBL1909156, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 1, AUC: 0.499
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 3, AUC: 0.499
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 1, AUC: 0.388
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 2, AUC: 0.725
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  48%|████▊     | 11/23 [02:23<02:29, 12.43s/it]
# Assay: CHEMBL1909156, Fold: 3, AUC: 0.495
# 0.0    315
# 1.0     27
# Name: CHEMBL1909211, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 2, AUC: 0.408
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 3, AUC: 0.575
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 1, AUC: 0.779
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 2, AUC: 0.656
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  52%|█████▏    | 12/23 [02:35<02:15, 12.32s/it]
# Assay: CHEMBL1909211, Fold: 3, AUC: 0.803
# 0.0    43
# 1.0    20
# Name: CHEMBL5291731, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 1, AUC: 0.200
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 2, AUC: 0.122
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 1, AUC: 0.522
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 2, AUC: 0.459
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  57%|█████▋    | 13/23 [02:45<01:54, 11.43s/it]
# Assay: CHEMBL5291731, Fold: 3, AUC: 0.704
# 0.0    66
# 1.0    35
# Name: CHEMBL5291732, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 2, AUC: 0.580
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 3, AUC: 0.541
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 1, AUC: 0.682
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 2, AUC: 0.701
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  61%|██████    | 14/23 [02:56<01:42, 11.39s/it]
# Assay: CHEMBL5291732, Fold: 3, AUC: 0.653
# 0.0    52
# 1.0    27
# Name: CHEMBL5291781, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 1, AUC: 0.451
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 1, AUC: 0.691
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 2, AUC: 0.686
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  65%|██████▌   | 15/23 [03:05<01:26, 10.77s/it]
# Assay: CHEMBL5291781, Fold: 3, AUC: 0.595
# 0.0    46
# 1.0    29
# Name: CHEMBL5291782, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 1, AUC: 0.535
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 2, AUC: 0.547
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 1, AUC: 0.535
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 2, AUC: 0.693
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  70%|██████▉   | 16/23 [03:15<01:12, 10.33s/it]
# Assay: CHEMBL5291782, Fold: 3, AUC: 0.740
# 0.0    50
# 1.0    38
# Name: CHEMBL5291809, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 1, AUC: 0.529
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 2, AUC: 0.583
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  74%|███████▍  | 17/23 [03:25<01:02, 10.37s/it]
# Assay: CHEMBL5291809, Fold: 3, AUC: 0.577
# 0.0    54
# 1.0    20
# Name: CHEMBL5291815, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 3, AUC: 0.481
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 1, AUC: 0.333
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 2, AUC: 0.373
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  78%|███████▊  | 18/23 [03:35<00:50, 10.09s/it]
# Assay: CHEMBL5291815, Fold: 3, AUC: 0.630
# 0.0    46
# 1.0    34
# Name: CHEMBL5291818, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 2, AUC: 0.467
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 3, AUC: 0.418
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 1, AUC: 0.557
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 2, AUC: 0.592
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  83%|████████▎ | 19/23 [03:45<00:40, 10.24s/it]
# Assay: CHEMBL5291818, Fold: 3, AUC: 0.552
# 0.0    35
# 1.0    30
# Name: CHEMBL5291822, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 1, AUC: 0.442
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 2, AUC: 0.533
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 1, AUC: 0.467
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 2, AUC: 0.575
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  87%|████████▋ | 20/23 [03:55<00:29,  9.96s/it]
# Assay: CHEMBL5291822, Fold: 3, AUC: 0.627
# 1.0    21
# 0.0    20
# Name: CHEMBL5291850, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 1, AUC: 0.612
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 2, AUC: 0.571
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 1, AUC: 0.918
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 2, AUC: 0.898
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  91%|█████████▏| 21/23 [04:06<00:20, 10.36s/it]
# Assay: CHEMBL5291850, Fold: 3, AUC: 0.762
# 0.0    64
# 1.0    22
# Name: CHEMBL5291892, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 1, AUC: 0.539
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 2, AUC: 0.732
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 3, AUC: 0.510
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 1, AUC: 0.708
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 2, AUC: 0.595
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  96%|█████████▌| 22/23 [04:15<00:10, 10.09s/it]
# Assay: CHEMBL5291892, Fold: 3, AUC: 0.510
# 0.0    67
# 1.0    29
# Name: CHEMBL5291899, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 1, AUC: 0.531
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 2, AUC: 0.505
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 1, AUC: 0.449
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 2, AUC: 0.639
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# 100%|██████████| 23/23 [04:26<00:00, 11.57s/it]
# Assay: CHEMBL5291899, Fold: 3, AUC: 0.423
