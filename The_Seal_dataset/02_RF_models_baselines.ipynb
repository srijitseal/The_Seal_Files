# %%
import pandas as pd

data = pd.read_csv("CP_all_Seal.csv")
data
# Out:
#                                InChICode_standardised_x  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1407  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1408  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1409  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1410  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1411  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#                              Standardized_SMILES_chembl  \
# 0                      COC(=O)Nc1nc2ccc(SC(C)C)cc2[nH]1
# 1                COCc1nc2c(=O)n(C)c(=O)n(CC(C)C)c2[nH]1
# 2                 Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 3     CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 4                               CC1=NN(c2ccccc2)C(=O)C1
# ...                                                 ...
# 1407                         CCn1c(O)nc2cc(Cl)c(Cl)cc21
# 1408                              Cc1nc(O)c2cccc(O)c2n1
# 1409                        N=C(N)NC(=O)Cc1c(Cl)cccc1Cl
# 1410                       Nc1ccc(S(=O)(=O)Nc2nccs2)cc1
# 1411                        Cc1no[nH]c1=NC(=O)Nc1cccnc1
#
#                               Standardized_InChI_chembl  \
# 0     InChI=1S/C12H15N3O2S/c1-7(2)18-8-4-5-9-10(6-8)...
# 1     InChI=1S/C12H18N4O3/c1-7(2)5-16-10-9(11(17)15(...
# 2     InChI=1S/C17H13NO3/c1-18-13-5-3-2-4-12(13)15(1...
# 3     InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 4     InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# ...                                                 ...
# 1407  InChI=1S/C9H8Cl2N2O/c1-2-13-8-4-6(11)5(10)3-7(...
# 1408  InChI=1S/C9H8N2O2/c1-5-10-8-6(9(13)11-5)3-2-4-...
# 1409  InChI=1S/C9H9Cl2N3O/c10-6-2-1-3-7(11)5(6)4-8(1...
# 1410  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 1411  InChI=1S/C9H9N5O2/c1-6-8(14-16-13-6)12-9(15)11...
#
#      Standardized_InChIKey_chembl      ChEMBL_ID  CHEMBL1741321  \
# 0     SXJIZQPZESTWLD-UHFFFAOYSA-N  CHEMBL1354363            0.0
# 1     NBLBCGUCPBXKOV-UHFFFAOYSA-N   CHEMBL307639            0.0
# 2     COBBNRKBTCBWQP-UHFFFAOYSA-N  CHEMBL1371756            1.0
# 3     GUGOEEXESWIERI-UHFFFAOYSA-N    CHEMBL17157            NaN
# 4     QELUYTUMUWHWMC-UHFFFAOYSA-N   CHEMBL290916            0.0
# ...                           ...            ...            ...
# 1407  LKHRMULASXZCLG-UHFFFAOYSA-N  CHEMBL1255655            NaN
# 1408  YJDAOHJWLUNFLX-UHFFFAOYSA-N   CHEMBL123904            1.0
# 1409  INJOMKTZOLKMBF-UHFFFAOYSA-N      CHEMBL862            0.0
# 1410  JNMRHUJNCSQMMB-UHFFFAOYSA-N      CHEMBL437            0.0
# 1411  NXRCDGIGKSHKAP-UHFFFAOYSA-N  CHEMBL1710820            0.0
#
#       CHEMBL1741322  CHEMBL1741323  CHEMBL1741324  CHEMBL1741325  ...  \
# 0               1.0            NaN            0.0            0.0  ...
# 1               1.0            0.0            NaN            0.0  ...
# 2               1.0            NaN            1.0            0.0  ...
# 3               NaN            NaN            NaN            NaN  ...
# 4               1.0            0.0            NaN            0.0  ...
# ...             ...            ...            ...            ...  ...
# 1407            1.0            0.0            1.0            0.0  ...
# 1408            1.0            1.0            0.0            1.0  ...
# 1409            0.0            0.0            0.0            NaN  ...
# 1410            0.0            0.0            0.0            NaN  ...
# 1411            1.0            0.0            0.0            0.0  ...
#
#       Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_3_0  \
# 0                            0.314918                        0.222859
# 1                            0.023860                       -0.016903
# 2                            0.052843                       -0.004288
# 3                            0.813737                        1.745136
# 4                           -0.059237                       -0.073432
# ...                               ...                             ...
# 1407                        -0.075060                       -0.082801
# 1408                        -0.058793                        0.027084
# 1409                        -0.046451                        0.001106
# 1410                         0.017906                       -0.026654
# 1411                        -0.099494                       -0.146276
#
#       Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                           0.280258                           0.192997
# 1                          -0.017773                          -0.028029
# 2                           0.025918                           0.020560
# 3                           1.483225                           0.531463
# 4                          -0.070867                          -0.037841
# ...                              ...                                ...
# 1407                       -0.096520                          -0.166819
# 1408                        0.010825                          -0.011973
# 1409                        0.007827                           0.004506
# 1410                       -0.007774                          -0.088286
# 1411                       -0.152421                          -0.096443
#
#       Nuclei_Texture_Variance_Mito_3_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                             0.144917                          0.168085
# 1                            -0.038308                         -0.041455
# 2                             0.004302                         -0.008033
# 3                             1.579915                          1.493236
# 4                            -0.081784                         -0.085790
# ...                                ...                               ...
# 1407                         -0.222268                         -0.208941
# 1408                         -0.033669                         -0.017549
# 1409                         -0.029183                         -0.005974
# 1410                         -0.052080                         -0.073599
# 1411                         -0.110563                         -0.126393
#
#       Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_3_0  \
# 0                            -0.332871                        -0.314733
# 1                            -0.070389                        -0.067789
# 2                            -0.056396                        -0.026962
# 3                            -0.703972                         0.540142
# 4                            -0.083668                        -0.064161
# ...                                ...                              ...
# 1407                         -0.008082                        -0.021377
# 1408                         -0.070822                        -0.041223
# 1409                         -0.077268                        -0.073622
# 1410                         -0.055808                        -0.070133
# 1411                         -0.048527                        -0.044408
#
#       Nuclei_Texture_Variance_RNA_5_0                     InChIKey
# 0                           -0.313477  SXJIZQPZESTWLD-UHFFFAOYSA-N
# 1                           -0.071673  NBLBCGUCPBXKOV-UHFFFAOYSA-N
# 2                           -0.039564  COBBNRKBTCBWQP-UHFFFAOYSA-N
# 3                            0.358874  GUGOEEXESWIERI-UHFFFAOYSA-N
# 4                           -0.074736  QELUYTUMUWHWMC-UHFFFAOYSA-N
# ...                               ...                          ...
# 1407                        -0.017203  LKHRMULASXZCLG-UHFFFAOYSA-N
# 1408                        -0.046780  YJDAOHJWLUNFLX-UHFFFAOYSA-N
# 1409                        -0.056681  INJOMKTZOLKMBF-UHFFFAOYSA-N
# 1410                        -0.061253  JNMRHUJNCSQMMB-UHFFFAOYSA-N
# 1411                        -0.064477  NXRCDGIGKSHKAP-UHFFFAOYSA-N
#
# [1412 rows x 1815 columns]

# %%
CellProfiler = data.columns.to_list()[31:-1]

# %%
assays_list = data.columns.to_list()[5:28]
len(assays_list)
assays_list
# Out:
# ['CHEMBL1741321',
#  'CHEMBL1741322',
#  'CHEMBL1741323',
#  'CHEMBL1741324',
#  'CHEMBL1741325',
#  'CHEMBL1909087',
#  'CHEMBL1909089',
#  'CHEMBL1909104',
#  'CHEMBL1909105',
#  'CHEMBL1909141',
#  'CHEMBL1909156',
#  'CHEMBL1909211',
#  'CHEMBL5291731',
#  'CHEMBL5291732',
#  'CHEMBL5291781',
#  'CHEMBL5291782',
#  'CHEMBL5291809',
#  'CHEMBL5291815',
#  'CHEMBL5291818',
#  'CHEMBL5291822',
#  'CHEMBL5291850',
#  'CHEMBL5291892',
#  'CHEMBL5291899']

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
import pandas as pd
from tqdm import tqdm
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.model_selection import RandomizedSearchCV
import os

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    roc_auc_score,
    matthews_corrcoef,
    confusion_matrix,
    roc_curve,
    precision_recall_curve,
    auc,
    cohen_kappa_score
)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_predict, RandomizedSearchCV
from sklearn.utils import class_weight
import pandas as pd
from tqdm import tqdm
from sklearn.utils import shuffle

# Function to calculate metrics
def calculate_metrics(y_true, y_pred_proba, threshold=0.5):
    y_pred_opt = (y_pred_proba >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred_opt).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    balanced_accuracy = (sensitivity + specificity) / 2
    mcc = matthews_corrcoef(y_true, y_pred_opt)
    kappa = cohen_kappa_score(y_true, y_pred_opt)
    
    # AUCPR
    precision, recall, _ = precision_recall_curve(y_true, y_pred_proba)
    aucpr = auc(recall, precision)
    
    # Cohen's Kappa at threshold 0.50
    kappa_at_50 = cohen_kappa_score(y_true, (y_pred_proba >= 0.50).astype(int))
    
    return {
        "Threshold": threshold,
        "Balanced Accuracy": balanced_accuracy,
        "Sensitivity": sensitivity,
        "Specificity": specificity,
        "MCC": mcc,
        "AUCPR": aucpr,
        "Cohen's Kappa": kappa,
        "Cohen's Kappa @ 0.50": kappa_at_50,
        "Confusion Matrix": {"TN": tn, "FP": fp, "FN": fn, "TP": tp},
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
    }

# Function to find the best threshold based on Cohen's Kappa
def find_best_threshold_for_kappa(y_true, y_pred_proba):
    thresholds = np.linspace(0, 1, 100)
    best_kappa = -1
    best_threshold = 0.5
    for threshold in thresholds:
        y_pred = (y_pred_proba >= threshold).astype(int)
        kappa = cohen_kappa_score(y_true, y_pred)
        if kappa > best_kappa:
            best_kappa = kappa
            best_threshold = threshold
    return best_threshold, best_kappa

# Initialize results
all_auc_scores = []

# Stratified splitting setup
stratified_kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Define the two sets of features
feature_sets = {
    "CellCount": ["Cells_Number_Object_Number"],  # Feature set cell count
    "CellProfiler": CellProfiler  # Feature set CP
}

# Loop through each assay to create individual models
for assay in tqdm(assays_list):
    
    # Filter out rows with missing values for the current assay
    assay_data = data[~data[assay].isna()].reset_index(drop=True)
    print(assay_data[assay].value_counts())
    
    # Extract labels
    y = assay_data[assay].astype(int)

    # Check for class imbalance
    if len(np.unique(y)) < 2:
        print(f"Skipping assay {assay} due to lack of positive/negative classes")
        continue
    
    # Calculate class weights
    class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y), y=y)
    class_weight_dict = {0: class_weights[0], 1: class_weights[1]}
    
    rf_param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [5, 10, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'class_weight': ['balanced']
    }
    
    logreg_param_grid = {
        'C': [0.01, 0.1, 1, 10, 100],
        'penalty': ['l1', 'l2'],
        'solver': ['liblinear']
    }
    
    for feature_set_name, feature_columns in feature_sets.items():
        
        # Extract features for the current feature set
        X = assay_data[feature_columns]

        for fold, (train_idx, test_idx) in enumerate(stratified_kfold.split(X, y)):
            X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
            y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
                 
            # Determine the model type based on the number of features
            if len(feature_columns) == 1:
                # Use Logistic Regression
                model = LogisticRegression(class_weight='balanced', random_state=42)
                param_grid = logreg_param_grid
            else:
                # Use Random Forest
                model = RandomForestClassifier(random_state=42, n_jobs=-1)
                param_grid = rf_param_grid

            # Perform RandomizedSearchCV
            random_search = RandomizedSearchCV(
                estimator=model,
                param_distributions=param_grid,
                n_iter=10,
                scoring='roc_auc',
                cv=3,
                n_jobs=-1,
                verbose=2,
                random_state=42
            )
            random_search.fit(X_train, y_train)

            # Best model
            best_model = random_search.best_estimator_

            # Generate OOB predictions for training data
            oob_pred_proba = cross_val_predict(
                best_model,
                X_train,
                y_train,
                cv=stratified_kfold,
                method='predict_proba'
            )[:, 1]
            
            # Optimize threshold using Cohen's Kappa
            opt_threshold, best_kappa = find_best_threshold_for_kappa(y_train, oob_pred_proba)
            
            # Test set predictions
            y_pred_proba = best_model.predict_proba(X_test)[:, 1]
            test_metrics = calculate_metrics(y_test, y_pred_proba, threshold=opt_threshold)
            
            # Random Y-scrambling
            y_train_scrambled = shuffle(y_train, random_state=fold)
            best_model.fit(X_train, y_train_scrambled)
            y_pred_proba_scrambled = best_model.predict_proba(X_test)[:, 1]
            scrambled_metrics = calculate_metrics(y_test, y_pred_proba_scrambled, threshold=0.50)
            
            # Collect results
            all_auc_scores.append({
                "Feature Set": feature_set_name,
                "Fold": fold + 1,
                "Task": assay,
                "AUC": roc_auc_score(y_test, y_pred_proba),
                "Optimal Threshold": opt_threshold,
                "Optimal Kappa": best_kappa,
                "Kappa": test_metrics["Cohen's Kappa"],
                "Kappa @ 0.50": test_metrics["Cohen's Kappa @ 0.50"],
                "Balanced Accuracy": test_metrics["Balanced Accuracy"],
                "AUCPR": test_metrics["AUCPR"],
                "Sensitivity": test_metrics["Sensitivity"],
                "Specificity": test_metrics["Specificity"],
                "MCC": test_metrics["MCC"],
                "TP": test_metrics["TP"],
                "TN": test_metrics["TN"],
                "FP": test_metrics["FP"],
                "FN": test_metrics["FN"],
                "Total Actives Train": sum(y_train),
                "Total Inactives Train": len(y_train) - sum(y_train),
                "Total Compounds Train": len(y_train),
                "Total Actives Test": sum(y_test),
                "Total Inactives Test": len(y_test) - sum(y_test),
                "Total Compounds Test": len(y_test),
                "Scrambled Kappa": scrambled_metrics["Cohen's Kappa"],
                "Scrambled Balanced Accuracy": scrambled_metrics["Balanced Accuracy"],
            })
            print(f"Assay: {assay}, Fold: {fold + 1}, AUC: {roc_auc_score(y_test, y_pred_proba):.3f}")
            # Convert results to DataFrame and save
            auc_df = pd.DataFrame(all_auc_scores)
            auc_df.to_csv("auc_scores_with_rf_kappa_thresholding_detailed.csv", index=False)


# Convert results to DataFrame and save
auc_df = pd.DataFrame(all_auc_scores)
auc_df.to_csv("auc_scores_with_rf_kappa_thresholding_detailed.csv", index=False)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]
# 0.0    614
# 1.0    232
# Name: CHEMBL1741321, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 1, AUC: 0.604
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 2, AUC: 0.610
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 3, AUC: 0.621
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 1, AUC: 0.639
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741321, Fold: 2, AUC: 0.615
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#   4%|▍         | 1/23 [00:16<05:53, 16.08s/it]
# Assay: CHEMBL1741321, Fold: 3, AUC: 0.680
# 1.0    429
# 0.0    341
# Name: CHEMBL1741322, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 1, AUC: 0.514
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 2, AUC: 0.595
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 3, AUC: 0.506
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 1, AUC: 0.618
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741322, Fold: 2, AUC: 0.648
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#   9%|▊         | 2/23 [00:31<05:24, 15.44s/it]
# Assay: CHEMBL1741322, Fold: 3, AUC: 0.606
# 0.0    509
# 1.0    340
# Name: CHEMBL1741323, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 1, AUC: 0.601
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 2, AUC: 0.544
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 3, AUC: 0.555
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 1, AUC: 0.810
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741323, Fold: 2, AUC: 0.763
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  13%|█▎        | 3/23 [00:44<04:53, 14.69s/it]
# Assay: CHEMBL1741323, Fold: 3, AUC: 0.791
# 0.0    505
# 1.0    277
# Name: CHEMBL1741324, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 1, AUC: 0.547
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 2, AUC: 0.554
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 3, AUC: 0.514
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 1, AUC: 0.635
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741324, Fold: 2, AUC: 0.669
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  17%|█▋        | 4/23 [01:00<04:47, 15.15s/it]
# Assay: CHEMBL1741324, Fold: 3, AUC: 0.634
# 0.0    543
# 1.0    262
# Name: CHEMBL1741325, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 1, AUC: 0.599
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 2, AUC: 0.608
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 3, AUC: 0.557
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 1, AUC: 0.800
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1741325, Fold: 2, AUC: 0.790
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  22%|██▏       | 5/23 [01:16<04:33, 15.22s/it]
# Assay: CHEMBL1741325, Fold: 3, AUC: 0.761
# 0.0    342
# 1.0     23
# Name: CHEMBL1909087, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 2, AUC: 0.302
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 1, AUC: 0.700
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909087, Fold: 2, AUC: 0.760
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  26%|██▌       | 6/23 [01:29<04:08, 14.59s/it]
# Assay: CHEMBL1909087, Fold: 3, AUC: 0.716
# 0.0    343
# 1.0     22
# Name: CHEMBL1909089, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 2, AUC: 0.285
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 3, AUC: 0.455
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 1, AUC: 0.494
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909089, Fold: 2, AUC: 0.661
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  30%|███       | 7/23 [01:42<03:47, 14.20s/it]
# Assay: CHEMBL1909089, Fold: 3, AUC: 0.776
# 0.0    339
# 1.0     26
# Name: CHEMBL1909104, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 1, AUC: 0.733
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909104, Fold: 2, AUC: 0.844
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  35%|███▍      | 8/23 [01:55<03:24, 13.62s/it]
# Assay: CHEMBL1909104, Fold: 3, AUC: 0.774
# 0.0    340
# 1.0     25
# Name: CHEMBL1909105, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 2, AUC: 0.353
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 1, AUC: 0.833
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909105, Fold: 2, AUC: 0.884
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  39%|███▉      | 9/23 [02:08<03:08, 13.44s/it]
# Assay: CHEMBL1909105, Fold: 3, AUC: 0.675
# 0.0    338
# 1.0     27
# Name: CHEMBL1909141, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 3, AUC: 0.302
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 1, AUC: 0.594
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909141, Fold: 2, AUC: 0.677
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  43%|████▎     | 10/23 [02:19<02:45, 12.75s/it]
# Assay: CHEMBL1909141, Fold: 3, AUC: 0.664
# 0.0    343
# 1.0     22
# Name: CHEMBL1909156, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 1, AUC: 0.343
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 2, AUC: 0.377
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 3, AUC: 0.568
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 1, AUC: 0.757
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909156, Fold: 2, AUC: 0.539
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  48%|████▊     | 11/23 [02:30<02:26, 12.22s/it]
# Assay: CHEMBL1909156, Fold: 3, AUC: 0.801
# 0.0    337
# 1.0     28
# Name: CHEMBL1909211, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 1, AUC: 0.347
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 1, AUC: 0.805
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL1909211, Fold: 2, AUC: 0.727
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  52%|█████▏    | 12/23 [02:41<02:10, 11.88s/it]
# Assay: CHEMBL1909211, Fold: 3, AUC: 0.626
# 0.0    46
# 1.0    21
# Name: CHEMBL5291731, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 1, AUC: 0.420
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 3, AUC: 0.362
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 1, AUC: 0.607
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291731, Fold: 2, AUC: 0.629
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  57%|█████▋    | 13/23 [02:53<01:59, 11.98s/it]
# Assay: CHEMBL5291731, Fold: 3, AUC: 0.500
# 0.0    71
# 1.0    36
# Name: CHEMBL5291732, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 3, AUC: 0.460
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 1, AUC: 0.719
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291732, Fold: 2, AUC: 0.639
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  61%|██████    | 14/23 [03:02<01:39, 11.09s/it]
# Assay: CHEMBL5291732, Fold: 3, AUC: 0.547
# 0.0    55
# 1.0    29
# Name: CHEMBL5291781, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 2, AUC: 0.389
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 1, AUC: 0.547
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291781, Fold: 2, AUC: 0.506
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  65%|██████▌   | 15/23 [03:13<01:27, 10.93s/it]
# Assay: CHEMBL5291781, Fold: 3, AUC: 0.428
# 0.0    48
# 1.0    30
# Name: CHEMBL5291782, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 1, AUC: 0.656
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 3, AUC: 0.631
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 1, AUC: 0.675
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291782, Fold: 2, AUC: 0.562
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  70%|██████▉   | 16/23 [03:21<01:11, 10.23s/it]
# Assay: CHEMBL5291782, Fold: 3, AUC: 0.628
# 0.0    54
# 1.0    39
# Name: CHEMBL5291809, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 3, AUC: 0.423
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 1, AUC: 0.564
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291809, Fold: 2, AUC: 0.483
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  74%|███████▍  | 17/23 [03:32<01:01, 10.33s/it]
# Assay: CHEMBL5291809, Fold: 3, AUC: 0.462
# 0.0    56
# 1.0    21
# Name: CHEMBL5291815, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 1, AUC: 0.414
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 2, AUC: 0.316
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 1, AUC: 0.346
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291815, Fold: 2, AUC: 0.429
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  78%|███████▊  | 18/23 [03:41<00:50, 10.04s/it]
# Assay: CHEMBL5291815, Fold: 3, AUC: 0.317
# 0.0    49
# 1.0    36
# Name: CHEMBL5291818, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 1, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 1, AUC: 0.652
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291818, Fold: 2, AUC: 0.391
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  83%|████████▎ | 19/23 [03:50<00:38,  9.64s/it]
# Assay: CHEMBL5291818, Fold: 3, AUC: 0.599
# 0.0    38
# 1.0    31
# Name: CHEMBL5291822, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 1, AUC: 0.369
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 2, AUC: 0.423
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 3, AUC: 0.492
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 1, AUC: 0.623
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291822, Fold: 2, AUC: 0.562
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  87%|████████▋ | 20/23 [04:00<00:29,  9.83s/it]
# Assay: CHEMBL5291822, Fold: 3, AUC: 0.455
# 0.0    23
# 1.0    22
# Name: CHEMBL5291850, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 1, AUC: 0.446
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 2, AUC: 0.768
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 3, AUC: 0.571
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 1, AUC: 0.732
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291850, Fold: 2, AUC: 0.911
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  91%|█████████▏| 21/23 [04:09<00:18,  9.44s/it]
# Assay: CHEMBL5291850, Fold: 3, AUC: 0.839
# 0.0    70
# 1.0    23
# Name: CHEMBL5291892, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 1, AUC: 0.446
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 1, AUC: 0.452
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291892, Fold: 2, AUC: 0.516
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
#  96%|█████████▌| 22/23 [04:20<00:10, 10.02s/it]
# Assay: CHEMBL5291892, Fold: 3, AUC: 0.495
# 0.0    72
# 1.0    31
# Name: CHEMBL5291899, dtype: int64
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 1, AUC: 0.481
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 2, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 3, AUC: 0.500
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 1, AUC: 0.348
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Assay: CHEMBL5291899, Fold: 2, AUC: 0.608
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# 100%|██████████| 23/23 [04:30<00:00, 11.76s/it]
# Assay: CHEMBL5291899, Fold: 3, AUC: 0.504
